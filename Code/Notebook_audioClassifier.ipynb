# %% [markdown]
# <a href="https://colab.research.google.com/github/C1587S/NN-AudioClassification/blob/master/Notebook_audioClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ========================
# importación y transformación de datos
# ========================
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import pylab as pylab
import IPython.display as ipd
from pathlib import Path

# ========================
# neuronal networks
# ========================
import random
import numpy as np

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torch.optim.lr_scheduler import ExponentialLR
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms


# ========================
# system
# ========================
import os
import copy
import time
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

class color:
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   CYAN = '\033[96m'
   END = '\033[0m'

# %% [markdown]
# # Transformación de datos

# %%
y,sr=librosa.load(file_to_open,duration=5)
sound,_=librosa.effects.trim(y)
librosa.display.waveplot(sound,sr=sr,alpha=0.5)

# %%
# aplicamos la transformada de fourier
n_fft=2048
D=np.abs(librosa.stft(sound[:n_fft],n_fft=n_fft,hop_length=n_fft+1))
plt.plot(D)

# %%
S = librosa.feature.melspectrogram(y=y, sr=sr)

plt.figure(figsize=(10, 4))
S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time',
                          y_axis='mel', sr=sr,
                          fmax=8000)
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()
g=""
plt.savefig('img.png')
plt.clf()

# %%
import IPython.display as ipd
ipd.Audio(file_to_open)

# %%
data_folder = Path("data/genres")
folder=Path("img_data/train_data")

    
genero=["blues",
       "classical",
       "country",
       "disco",
       "hiphop",
       "jazz",
       "metal",
       "pop",
       "reggae",
       "rock"]

file_type=".wav"


#recorre todos los datos
y=[]
sr=[]
for i in range(10):
    print(i)
    folder=Path("img_data/train_data")
    for j in range(100):
        
        #paths para recorrer carpetas
        if j<10:
            file_name= genero[i]+".0000"+str(j)+file_type
            file_to_open= data_folder / genero[i] / file_name
        else:
            file_name= genero[i]+".000"+str(j)+file_type
            file_to_open= data_folder / genero[i] / file_name
            
        #lee el archivo de audio
        y,sr=librosa.load(file_to_open, duration=30)
        
        #genera el espectograma
        S=librosa.feature.melspectrogram(y=y,
                                         sr=sr,
                                         n_fft=1024,
                                         hop_length=512)
        
        S_dB = librosa.power_to_db(S, ref=np.max)  #pasa a decibeles
        ST=np.transpose(S_dB)
    
        pylab.figure(figsize=(3,3))
        pylab.axis('off') 
        pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
        librosa.display.specshow(ST)#, cmap="gray")
        
        
        if j<10:
            file_name= genero[i]+".0000"+str(j)+".jpg"
            save= folder / genero[i] / file_name
        else:
            file_name= genero[i]+".000"+str(j)+".jpg"
            save= folder / genero[i] / file_name     
        
        if j==79:
            folder=Path("img_data/test_data")
        
        pylab.savefig(save, bbox_inches=None, pad_inches=0)
        pylab.close()

# %% [markdown]
# # Importación de datos

# %%
# Conectar a la nube (collab):
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Cambiar el directorio al local (collab):
cd drive/My Drive/AudioClassifier/NN-AudioClassification/
# Out:
# /content/drive/My Drive/AudioClassifier/NN-AudioClassification

# %%
input_size  = 3*216*216 # Dimension de datos de entrada (28 x 28)
num_classes = 10        # MNIST tiene 10 clases (numeros del 1 al 10)
num_epochs  = 15        # Numero de epocas para entrenar
bs          = 20        # Tamano de lote (batch_size)

# %%
traindir = "img_data/train_data"
testdir  = "img_data/test_data"
data_dir = "img_data"
# cargar datos para todos los batchsizes
train_loader, test_loader = load_dataset(traindir, testdir)

# %%
# para checar las dimensiones de la imagen
for i, (xi, yi) in enumerate(test_loader):
            print(xi.shape)
            print(yi.shape)

# %% [markdown]
# **Test para diferentes tamaños del batch**
# - sin dropout en la red neuronal de 2 capas escondidas (200 y 60 unidades)
#
# | batch-size | precision | perdida |
# |------------|-----------|---------|
# |     10     |     10%   |  2.31   |
# |     15     |     31%   |  1.30   |
# |   **20**   |   **32%** |**1.45** |
# |     21     |     26%   |  1.19   |
# |     25     |     30%   |  1.11   |
# |     30     |     25%   |  1.13   |
# |     50     |     19%   |  1.78   |
#
# Dado lo anterior se fijóó el bs en 20.
#
# Ahora bien, la precisión no se estandariza. Se aumenta el núúmero de épocas a 15.

# %%
torch.manual_seed(123456789)
dropout_prob = 0.5 
input_size   = 3*216*216
num_epochs   = 5
num_classes  = 10
gamma        = 0.6 # ajsute exponencial
modelo_test  = RedNeuronal2_ReLu(input_size, num_classes).to(device)

entrenamiento_redesProf(model = modelo_test, 
                        input_size = 3*216*216, 
                        lr = 0.001, 
                        num_epochs = 10, 
                        num_classes = 10)
# Out:
# Epoca: 1/10, Paso: 10/40, Perdida:11.25086
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 1/10, Paso: 20/40, Perdida:2.65754
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 1/10, Paso: 30/40, Perdida:4.62649
# Precision del modelo en 200 canciones: 26.0 %
# Epoca: 1/10, Paso: 40/40, Perdida:2.19070
# Precision del modelo en 200 canciones: 24.0 %
# Epoca: 2/10, Paso: 10/40, Perdida:2.33962
# Precision del modelo en 200 canciones: 17.0 %
# Epoca: 2/10, Paso: 20/40, Perdida:1.96917
# Precision del modelo en 200 canciones: 28.0 %
# Epoca: 2/10, Paso: 30/40, Perdida:2.10370
# Precision del modelo en 200 canciones: 25.5 %
# Epoca: 2/10, Paso: 40/40, Perdida:2.42548
# Precision del modelo en 200 canciones: 10.5 %
# Epoca: 3/10, Paso: 10/40, Perdida:1.98747
# Precision del modelo en 200 canciones: 22.0 %
# Epoca: 3/10, Paso: 20/40, Perdida:1.97048
# Precision del modelo en 200 canciones: 19.5 %
# Epoca: 3/10, Paso: 30/40, Perdida:2.72560
# Precision del modelo en 200 canciones: 9.0 %
# Epoca: 3/10, Paso: 40/40, Perdida:1.67024
# Precision del modelo en 200 canciones: 21.5 %
# Epoca: 4/10, Paso: 10/40, Perdida:1.89571
# Precision del modelo en 200 canciones: 17.0 %
# Epoca: 4/10, Paso: 20/40, Perdida:1.74625
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 4/10, Paso: 30/40, Perdida:1.69871
# Precision del modelo en 200 canciones: 19.5 %
# Epoca: 4/10, Paso: 40/40, Perdida:1.70761
# Precision del modelo en 200 canciones: 18.0 %
# Epoca: 5/10, Paso: 10/40, Perdida:1.51187
# Precision del modelo en 200 canciones: 26.0 %
# Epoca: 5/10, Paso: 20/40, Perdida:1.53326
# Precision del modelo en 200 canciones: 21.5 %
# Epoca: 5/10, Paso: 30/40, Perdida:1.69096
# Precision del modelo en 200 canciones: 30.5 %
# Epoca: 5/10, Paso: 40/40, Perdida:1.95600
# Precision del modelo en 200 canciones: 25.5 %
# Epoca: 6/10, Paso: 10/40, Perdida:1.60554
# Precision del modelo en 200 canciones: 19.0 %
# Epoca: 6/10, Paso: 20/40, Perdida:1.54920
# Precision del modelo en 200 canciones: 17.0 %
# Epoca: 6/10, Paso: 30/40, Perdida:1.78612
# Precision del modelo en 200 canciones: 28.0 %
# Epoca: 6/10, Paso: 40/40, Perdida:1.46337
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 7/10, Paso: 10/40, Perdida:1.55730
# Precision del modelo en 200 canciones: 27.5 %
# Epoca: 7/10, Paso: 20/40, Perdida:1.57610
# Precision del modelo en 200 canciones: 23.5 %
# Epoca: 7/10, Paso: 30/40, Perdida:1.49628
# Precision del modelo en 200 canciones: 31.5 %
# Epoca: 7/10, Paso: 40/40, Perdida:1.30877
# Precision del modelo en 200 canciones: 22.0 %
# Epoca: 8/10, Paso: 10/40, Perdida:1.12808
# Precision del modelo en 200 canciones: 23.5 %
# Epoca: 8/10, Paso: 20/40, Perdida:0.99149
# Precision del modelo en 200 canciones: 29.0 %
# Epoca: 8/10, Paso: 30/40, Perdida:1.26005
# Precision del modelo en 200 canciones: 28.0 %
# Epoca: 8/10, Paso: 40/40, Perdida:1.80652
# Precision del modelo en 200 canciones: 24.5 %
# Epoca: 9/10, Paso: 10/40, Perdida:1.79479
# Precision del modelo en 200 canciones: 17.5 %
# Epoca: 9/10, Paso: 20/40, Perdida:1.66155
# Precision del modelo en 200 canciones: 28.5 %
# Epoca: 9/10, Paso: 30/40, Perdida:1.65025
# Precision del modelo en 200 canciones: 30.5 %
# Epoca: 9/10, Paso: 40/40, Perdida:2.24032
# Precision del modelo en 200 canciones: 37.5 %
# Epoca: 10/10, Paso: 10/40, Perdida:1.29717
# Precision del modelo en 200 canciones: 28.5 %
# Epoca: 10/10, Paso: 20/40, Perdida:1.57163
# Precision del modelo en 200 canciones: 28.0 %
# Epoca: 10/10, Paso: 30/40, Perdida:1.37104
# Precision del modelo en 200 canciones: 21.5 %
# Epoca: 10/10, Paso: 40/40, Perdida:1.23909
# Precision del modelo en 200 canciones: 21.0 %
# ==================================================
# Tasa de aprendizaje: 0.001
# ==================================================

# %% [markdown]
# En el anterior ejercicio se definió el batch size de 20, y se observa que la precisióón tiende a estar entre el 30% y 40%.
#
# Ahora se procede a entrenar varios modelos con redes profundas.

# %%
# Red neuronal de 1 capa escondida  (500 unidades) con activaciones ReLU
RN1_ReLu = RedNeuronal1_ReLu(input_size, num_classes).to(device)

# Red neuronal de 2 capas escondidas (200, 60 unidades)
RN2_ReLu = RedNeuronal2_ReLu(input_size, num_classes).to(device)

# Red neuronal de 3 capas escondidas (500, 100 y 30 unidades) 
RN3_ReLu = RedNeuronal3_ReLu(input_size, num_classes).to(device)

# Red neuronal de 5 capas escondidas (500, 300, 100, 50, 30 unidades)
RN5_ReLu = RedNeuronal5_ReLu(input_size, num_classes).to(device)

# lista de redes profundas
modelos_redesProfundas = [RN1_ReLu, RN2_ReLu, RN3_ReLu, RN5_ReLu]

# %% [markdown]
# Entrenamiento de las redes

# %%
count = 0
for modelo_evaluado in modelos_redesProfundas:
    print("="*90) 
    if count == 0:
        print('Red neuronal de 1 capa escondida  (500 unidades) con activaciones ReLU')
        print("="*90) 
        count += 1           
    elif count == 1:
        print('Red neuronal de 2 capas escondidas (200, 60 unidades)')
        print("="*90) 
        count += 1        
    elif count == 2:
        print('Red neuronal de 3 capas escondidas (500, 100 y 30 unidades) ')
        print("="*90) 
        count += 1
    else:
        print('Red neuronal de 5 capas escondidas (500, 300, 100, 50, 30 unidades)')
        print("="*90) 
        count += 1

    # entrenamiento
    entrenamiento_redesProf(model= modelo_evaluado, 
                        input_size= 3*216*216, 
                        lr=0.001, 
                        num_epochs=10, 
                        num_classes=10)
    print("="*90)
# Out:
# ==========================================================================================
# Red neuronal de 1 capa escondida  (500 unidades) con activaciones ReLU
# ==========================================================================================
# Epoca: 1/10, Paso: 10/40, Perdida:2.28625
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 1/10, Paso: 20/40, Perdida:2.42022
# Precision del modelo en 200 canciones: 13.0 %
# Epoca: 1/10, Paso: 30/40, Perdida:2.42052
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 1/10, Paso: 40/40, Perdida:2.35391
# Precision del modelo en 200 canciones: 17.0 %
# Epoca: 2/10, Paso: 10/40, Perdida:2.33805
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 2/10, Paso: 20/40, Perdida:2.31831
# Precision del modelo en 200 canciones: 17.0 %
# Epoca: 2/10, Paso: 30/40, Perdida:2.32302
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 2/10, Paso: 40/40, Perdida:2.41674
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 3/10, Paso: 10/40, Perdida:2.32429
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 3/10, Paso: 20/40, Perdida:2.30406
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 3/10, Paso: 30/40, Perdida:2.32786
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 3/10, Paso: 40/40, Perdida:2.46467
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 4/10, Paso: 10/40, Perdida:2.42742
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 4/10, Paso: 20/40, Perdida:2.32182
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 4/10, Paso: 30/40, Perdida:2.47413
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 4/10, Paso: 40/40, Perdida:2.28128
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 5/10, Paso: 10/40, Perdida:2.38188
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 5/10, Paso: 20/40, Perdida:2.32377
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 5/10, Paso: 30/40, Perdida:2.34772
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 5/10, Paso: 40/40, Perdida:2.32725
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 6/10, Paso: 10/40, Perdida:2.44108
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 6/10, Paso: 20/40, Perdida:2.43782
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 6/10, Paso: 30/40, Perdida:2.43845
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 6/10, Paso: 40/40, Perdida:2.31378
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 7/10, Paso: 10/40, Perdida:2.34588
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 7/10, Paso: 20/40, Perdida:2.34362
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 7/10, Paso: 30/40, Perdida:2.31656
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 7/10, Paso: 40/40, Perdida:2.36521
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 8/10, Paso: 10/40, Perdida:2.32483
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 8/10, Paso: 20/40, Perdida:2.36843
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 8/10, Paso: 30/40, Perdida:2.35209
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 8/10, Paso: 40/40, Perdida:2.29403
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 9/10, Paso: 10/40, Perdida:2.31430
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 9/10, Paso: 20/40, Perdida:2.43343
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 9/10, Paso: 30/40, Perdida:2.28652
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 9/10, Paso: 40/40, Perdida:2.26234
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 10/10, Paso: 10/40, Perdida:2.32222
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 10/10, Paso: 20/40, Perdida:2.36343
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 10/10, Paso: 30/40, Perdida:2.36929
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 10/10, Paso: 40/40, Perdida:2.31456
# Precision del modelo en 200 canciones: 10.0 %
# ==================================================
# Tasa de aprendizaje: 0.001
# ==================================================
# ==========================================================================================
# ==========================================================================================
# Red neuronal de 2 capas escondidas (200, 60 unidades)
# ==========================================================================================
# Epoca: 1/10, Paso: 10/40, Perdida:5.84210
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 1/10, Paso: 20/40, Perdida:3.42391
# Precision del modelo en 200 canciones: 15.0 %
# Epoca: 1/10, Paso: 30/40, Perdida:2.81973
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 1/10, Paso: 40/40, Perdida:2.91913
# Precision del modelo en 200 canciones: 22.0 %
# Epoca: 2/10, Paso: 10/40, Perdida:2.20136
# Precision del modelo en 200 canciones: 20.0 %
# Epoca: 2/10, Paso: 20/40, Perdida:1.99838
# Precision del modelo en 200 canciones: 24.0 %
# Epoca: 2/10, Paso: 30/40, Perdida:1.70601
# Precision del modelo en 200 canciones: 17.5 %
# Epoca: 2/10, Paso: 40/40, Perdida:3.05537
# Precision del modelo en 200 canciones: 16.5 %
# Epoca: 3/10, Paso: 10/40, Perdida:1.50359
# Precision del modelo en 200 canciones: 14.0 %
# Epoca: 3/10, Paso: 20/40, Perdida:1.46883
# Precision del modelo en 200 canciones: 14.0 %
# Epoca: 3/10, Paso: 30/40, Perdida:1.59078
# Precision del modelo en 200 canciones: 34.0 %
# Epoca: 3/10, Paso: 40/40, Perdida:1.48265
# Precision del modelo en 200 canciones: 27.0 %
# Epoca: 4/10, Paso: 10/40, Perdida:1.42734
# Precision del modelo en 200 canciones: 21.5 %
# Epoca: 4/10, Paso: 20/40, Perdida:2.01019
# Precision del modelo en 200 canciones: 24.0 %
# Epoca: 4/10, Paso: 30/40, Perdida:1.89076
# Precision del modelo en 200 canciones: 27.5 %
# Epoca: 4/10, Paso: 40/40, Perdida:1.54444
# Precision del modelo en 200 canciones: 32.0 %
# Epoca: 5/10, Paso: 10/40, Perdida:1.26651
# Precision del modelo en 200 canciones: 34.0 %
# Epoca: 5/10, Paso: 20/40, Perdida:1.60624
# Precision del modelo en 200 canciones: 32.5 %
# Epoca: 5/10, Paso: 30/40, Perdida:1.79915
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 5/10, Paso: 40/40, Perdida:1.60641
# Precision del modelo en 200 canciones: 27.0 %
# Epoca: 6/10, Paso: 10/40, Perdida:1.88509
# Precision del modelo en 200 canciones: 21.0 %
# Epoca: 6/10, Paso: 20/40, Perdida:1.10658
# Precision del modelo en 200 canciones: 28.0 %
# Epoca: 6/10, Paso: 30/40, Perdida:1.78691
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 6/10, Paso: 40/40, Perdida:1.19202
# Precision del modelo en 200 canciones: 30.0 %
# Epoca: 7/10, Paso: 10/40, Perdida:1.40346
# Precision del modelo en 200 canciones: 27.0 %
# Epoca: 7/10, Paso: 20/40, Perdida:2.17068
# Precision del modelo en 200 canciones: 26.0 %
# Epoca: 7/10, Paso: 30/40, Perdida:1.24126
# Precision del modelo en 200 canciones: 21.0 %
# Epoca: 7/10, Paso: 40/40, Perdida:1.21973
# Precision del modelo en 200 canciones: 36.0 %
# Epoca: 8/10, Paso: 10/40, Perdida:1.92608
# Precision del modelo en 200 canciones: 29.5 %
# Epoca: 8/10, Paso: 20/40, Perdida:1.35176
# Precision del modelo en 200 canciones: 27.0 %
# Epoca: 8/10, Paso: 30/40, Perdida:1.73892
# Precision del modelo en 200 canciones: 20.5 %
# Epoca: 8/10, Paso: 40/40, Perdida:1.85213
# Precision del modelo en 200 canciones: 30.0 %
# Epoca: 9/10, Paso: 10/40, Perdida:1.68614
# Precision del modelo en 200 canciones: 23.0 %
# Epoca: 9/10, Paso: 20/40, Perdida:1.38026
# Precision del modelo en 200 canciones: 28.0 %
# Epoca: 9/10, Paso: 30/40, Perdida:1.55539
# Precision del modelo en 200 canciones: 26.0 %
# Epoca: 9/10, Paso: 40/40, Perdida:0.97291
# Precision del modelo en 200 canciones: 28.0 %
# Epoca: 10/10, Paso: 10/40, Perdida:1.28048
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 10/10, Paso: 20/40, Perdida:0.74128
# Precision del modelo en 200 canciones: 29.0 %
# Epoca: 10/10, Paso: 30/40, Perdida:1.14000
# Precision del modelo en 200 canciones: 24.5 %
# Epoca: 10/10, Paso: 40/40, Perdida:0.82157
# Precision del modelo en 200 canciones: 19.0 %
# ==================================================
# Tasa de aprendizaje: 0.001
# ==================================================
# ==========================================================================================
# ==========================================================================================
# Red neuronal de 3 capas escondidas (500, 100 y 30 unidades)
# ==========================================================================================
# Epoca: 1/10, Paso: 10/40, Perdida:9.44795
# Precision del modelo en 200 canciones: 12.0 %
# Epoca: 1/10, Paso: 20/40, Perdida:2.56583
# Precision del modelo en 200 canciones: 18.5 %
# Epoca: 1/10, Paso: 30/40, Perdida:2.16763
# Precision del modelo en 200 canciones: 23.5 %
# Epoca: 1/10, Paso: 40/40, Perdida:2.20809
# Precision del modelo en 200 canciones: 20.5 %
# Epoca: 2/10, Paso: 10/40, Perdida:1.81778
# Precision del modelo en 200 canciones: 17.5 %
# Epoca: 2/10, Paso: 20/40, Perdida:1.99443
# Precision del modelo en 200 canciones: 23.0 %
# Epoca: 2/10, Paso: 30/40, Perdida:1.82394
# Precision del modelo en 200 canciones: 31.0 %
# Epoca: 2/10, Paso: 40/40, Perdida:2.19360
# Precision del modelo en 200 canciones: 29.5 %
# Epoca: 3/10, Paso: 10/40, Perdida:1.69352
# Precision del modelo en 200 canciones: 20.0 %
# Epoca: 3/10, Paso: 20/40, Perdida:2.21401
# Precision del modelo en 200 canciones: 23.0 %
# Epoca: 3/10, Paso: 30/40, Perdida:1.45648
# Precision del modelo en 200 canciones: 22.0 %
# Epoca: 3/10, Paso: 40/40, Perdida:1.72630
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 4/10, Paso: 10/40, Perdida:1.70864
# Precision del modelo en 200 canciones: 30.0 %
# Epoca: 4/10, Paso: 20/40, Perdida:1.59075
# Precision del modelo en 200 canciones: 22.5 %
# Epoca: 4/10, Paso: 30/40, Perdida:1.85968
# Precision del modelo en 200 canciones: 27.0 %
# Epoca: 4/10, Paso: 40/40, Perdida:1.77998
# Precision del modelo en 200 canciones: 32.5 %
# Epoca: 5/10, Paso: 10/40, Perdida:1.69489
# Precision del modelo en 200 canciones: 29.0 %
# Epoca: 5/10, Paso: 20/40, Perdida:1.63011
# Precision del modelo en 200 canciones: 24.5 %
# Epoca: 5/10, Paso: 30/40, Perdida:1.49525
# Precision del modelo en 200 canciones: 31.0 %
# Epoca: 5/10, Paso: 40/40, Perdida:1.69594
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 6/10, Paso: 10/40, Perdida:1.65214
# Precision del modelo en 200 canciones: 24.0 %
# Epoca: 6/10, Paso: 20/40, Perdida:1.67337
# Precision del modelo en 200 canciones: 27.0 %
# Epoca: 6/10, Paso: 30/40, Perdida:1.74311
# Precision del modelo en 200 canciones: 33.0 %
# Epoca: 6/10, Paso: 40/40, Perdida:1.47444
# Precision del modelo en 200 canciones: 14.5 %
# Epoca: 7/10, Paso: 10/40, Perdida:1.52880
# Precision del modelo en 200 canciones: 34.5 %
# Epoca: 7/10, Paso: 20/40, Perdida:1.17423
# Precision del modelo en 200 canciones: 30.0 %
# Epoca: 7/10, Paso: 30/40, Perdida:1.70793
# Precision del modelo en 200 canciones: 31.0 %
# Epoca: 7/10, Paso: 40/40, Perdida:1.67726
# Precision del modelo en 200 canciones: 29.5 %
# Epoca: 8/10, Paso: 10/40, Perdida:1.34933
# Precision del modelo en 200 canciones: 28.5 %
# Epoca: 8/10, Paso: 20/40, Perdida:1.42474
# Precision del modelo en 200 canciones: 30.0 %
# Epoca: 8/10, Paso: 30/40, Perdida:1.09654
# Precision del modelo en 200 canciones: 30.0 %
# Epoca: 8/10, Paso: 40/40, Perdida:1.43346
# Precision del modelo en 200 canciones: 33.0 %
# Epoca: 9/10, Paso: 10/40, Perdida:2.04029
# Precision del modelo en 200 canciones: 31.5 %
# Epoca: 9/10, Paso: 20/40, Perdida:1.45844
# Precision del modelo en 200 canciones: 31.0 %
# Epoca: 9/10, Paso: 30/40, Perdida:1.06023
# Precision del modelo en 200 canciones: 29.0 %
# Epoca: 9/10, Paso: 40/40, Perdida:1.52406
# Precision del modelo en 200 canciones: 33.0 %
# Epoca: 10/10, Paso: 10/40, Perdida:1.45640
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 10/10, Paso: 20/40, Perdida:1.60665
# Precision del modelo en 200 canciones: 33.5 %
# Epoca: 10/10, Paso: 30/40, Perdida:1.45402
# Precision del modelo en 200 canciones: 25.5 %
# Epoca: 10/10, Paso: 40/40, Perdida:1.20923
# Precision del modelo en 200 canciones: 33.5 %
# ==================================================
# Tasa de aprendizaje: 0.001
# ==================================================
# ==========================================================================================
# ==========================================================================================
# Red neuronal de 5 capas escondidas (500, 300, 100, 50, 30 unidades)
# ==========================================================================================
# Epoca: 1/10, Paso: 10/40, Perdida:3.27239
# Precision del modelo en 200 canciones: 10.0 %
# Epoca: 1/10, Paso: 20/40, Perdida:2.43212
# Precision del modelo en 200 canciones: 18.0 %
# Epoca: 1/10, Paso: 30/40, Perdida:2.30839
# Precision del modelo en 200 canciones: 15.0 %
# Epoca: 1/10, Paso: 40/40, Perdida:2.27017
# Precision del modelo en 200 canciones: 16.0 %
# Epoca: 2/10, Paso: 10/40, Perdida:2.10580
# Precision del modelo en 200 canciones: 20.0 %
# Epoca: 2/10, Paso: 20/40, Perdida:1.99701
# Precision del modelo en 200 canciones: 25.0 %
# Epoca: 2/10, Paso: 30/40, Perdida:1.93958
# Precision del modelo en 200 canciones: 25.5 %
# Epoca: 2/10, Paso: 40/40, Perdida:2.14099
# Precision del modelo en 200 canciones: 16.0 %
# Epoca: 3/10, Paso: 10/40, Perdida:1.99795
# Precision del modelo en 200 canciones: 14.5 %
# Epoca: 3/10, Paso: 20/40, Perdida:2.05218
# Precision del modelo en 200 canciones: 25.0 %
# Epoca: 3/10, Paso: 30/40, Perdida:2.02103
# Precision del modelo en 200 canciones: 29.0 %
# Epoca: 3/10, Paso: 40/40, Perdida:1.78174
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 4/10, Paso: 10/40, Perdida:1.97530
# Precision del modelo en 200 canciones: 17.0 %
# Epoca: 4/10, Paso: 20/40, Perdida:1.76417
# Precision del modelo en 200 canciones: 25.5 %
# Epoca: 4/10, Paso: 30/40, Perdida:1.87368
# Precision del modelo en 200 canciones: 14.0 %
# Epoca: 4/10, Paso: 40/40, Perdida:1.84132
# Precision del modelo en 200 canciones: 19.0 %
# Epoca: 5/10, Paso: 10/40, Perdida:1.71479
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 5/10, Paso: 20/40, Perdida:2.30877
# Precision del modelo en 200 canciones: 21.5 %
# Epoca: 5/10, Paso: 30/40, Perdida:1.78113
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 5/10, Paso: 40/40, Perdida:2.29503
# Precision del modelo en 200 canciones: 29.5 %
# Epoca: 6/10, Paso: 10/40, Perdida:1.52663
# Precision del modelo en 200 canciones: 20.5 %
# Epoca: 6/10, Paso: 20/40, Perdida:1.86334
# Precision del modelo en 200 canciones: 29.0 %
# Epoca: 6/10, Paso: 30/40, Perdida:1.97519
# Precision del modelo en 200 canciones: 25.5 %
# Epoca: 6/10, Paso: 40/40, Perdida:1.77424
# Precision del modelo en 200 canciones: 20.0 %
# Epoca: 7/10, Paso: 10/40, Perdida:1.84019
# Precision del modelo en 200 canciones: 25.5 %
# Epoca: 7/10, Paso: 20/40, Perdida:1.97958
# Precision del modelo en 200 canciones: 24.5 %
# Epoca: 7/10, Paso: 30/40, Perdida:1.52394
# Precision del modelo en 200 canciones: 23.5 %
# Epoca: 7/10, Paso: 40/40, Perdida:2.24798
# Precision del modelo en 200 canciones: 18.0 %
# Epoca: 8/10, Paso: 10/40, Perdida:1.72312
# Precision del modelo en 200 canciones: 15.5 %
# Epoca: 8/10, Paso: 20/40, Perdida:1.99093
# Precision del modelo en 200 canciones: 28.5 %
# Epoca: 8/10, Paso: 30/40, Perdida:1.86272
# Precision del modelo en 200 canciones: 23.5 %
# Epoca: 8/10, Paso: 40/40, Perdida:1.82146
# Precision del modelo en 200 canciones: 28.5 %
# Epoca: 9/10, Paso: 10/40, Perdida:2.17931
# Precision del modelo en 200 canciones: 23.5 %
# Epoca: 9/10, Paso: 20/40, Perdida:1.31799
# Precision del modelo en 200 canciones: 26.5 %
# Epoca: 9/10, Paso: 30/40, Perdida:1.71021
# Precision del modelo en 200 canciones: 27.5 %
# Epoca: 9/10, Paso: 40/40, Perdida:1.78257
# Precision del modelo en 200 canciones: 24.0 %
# Epoca: 10/10, Paso: 10/40, Perdida:1.63097
# Precision del modelo en 200 canciones: 30.0 %
# Epoca: 10/10, Paso: 20/40, Perdida:1.95725
# Precision del modelo en 200 canciones: 29.5 %
# Epoca: 10/10, Paso: 30/40, Perdida:2.23854
# Precision del modelo en 200 canciones: 19.5 %
# Epoca: 10/10, Paso: 40/40, Perdida:1.59458
# Precision del modelo en 200 canciones: 27.0 %
# ==================================================
# Tasa de aprendizaje: 0.001
# ==================================================
# ==========================================================================================

# %% [markdown]
# # Redes convolucionales
#
# Utilizando modelos pre-entrenados de `torchvision`.
#
# - Primero se deben estandarizar los datos
# - Después se deben ajustar las dimensiones de las arquitecturas

# %%
# cargar datos (apendice)
train_loader_norm, val_loader_norm = load_normalized_dataset()

# %%
num_classes = 10
batch_size = 20
num_epochs = 15
feature_extract = True

from torchvision import models
# available models
# dir(models)

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %% [markdown]
# A continuación se ajustan las siguientes arquitecturas:
#
# - `alexnet`
# - `resnet18`
# - `vgg11_bn` (normalización de batches)
# - `densenet121`

# %%
in_features = 3*224*224
feature_extract = True
use_pretrained = True
num_classes = 10

## alexnet
model_ft_alexnet = models.alexnet(pretrained=use_pretrained)
set_parameter_requires_grad(model_ft_alexnet, feature_extract)
num_ftrs = model_ft_alexnet.classifier[6].in_features
model_ft_alexnet.classifier[6] = nn.Linear(num_ftrs,num_classes)
# print(model_ft_alexnet)

## resnet18
model_ft_resnet18 = models.resnet18(pretrained=use_pretrained)
set_parameter_requires_grad(model_ft_resnet18, feature_extract)
num_ftrs = model_ft_resnet18.fc.in_features
model_ft_resnet18.fc = nn.Linear(num_ftrs, num_classes)
input_size = 224

## vgg11_bn
model_ft_vgg11bn = models.vgg11_bn(pretrained=use_pretrained)
set_parameter_requires_grad(model_ft_vgg11bn, feature_extract)
num_ftrs = model_ft_vgg11bn.classifier[6].in_features
model_ft_vgg11bn.classifier[6] = nn.Linear(num_ftrs,num_classes)
input_size = 224

## densenet121
model_ft_densenet121 = models.densenet121(pretrained=use_pretrained)
set_parameter_requires_grad(model_ft_densenet121, feature_extract)
num_ftrs = model_ft_densenet121.classifier.in_features
model_ft_densenet121.classifier = nn.Linear(num_ftrs, num_classes)
input_size = 224


# lista de arquitecturas
modelos_cnn = [model_ft_alexnet, 
              model_ft_resnet18, 
              model_ft_vgg11bn, 
              model_ft_densenet121]
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# 100%|██████████| 233M/233M [00:04<00:00, 55.4MB/s]
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100%|██████████| 44.7M/44.7M [00:02<00:00, 18.9MB/s]
# Downloading: "https://download.pytorch.org/models/vgg11_bn-6002323d.pth" to /root/.cache/torch/checkpoints/vgg11_bn-6002323d.pth
# 100%|██████████| 507M/507M [00:07<00:00, 72.1MB/s]
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 62.3MB/s]

# %% [markdown]
# Entrenamiento de las arquitecturas

# %% [markdown]
# **batch size: 10**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
batch_size = 10
bs = batch_size
train_loader_norm, val_loader_norm = load_normalized_dataset(batch_size)
  # evaluación de los modelos de cnn
count = 0
for modelo_evaluado in modelos_cnn:
  print("="*90)
  if count == 0:
    print("device: ", device)
    print('arquitectura: Alexnet')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1           
  elif count == 1:
    print("device: ", device)
    print('arquitectura: resnet18')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1        
  elif count == 2:
    print("device: ", device)
    print('arquitectura: vgg11_bn')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1
  else:
    print("device: ", device)
    print('arquitectura: densenet121')
    print("="*90) 
    count += 1

  # entrenamiento
  entrenamiento_cnn1(modelo_evaluado, lr=.001, gamma=0.6,
                       num_classes = 10, num_epochs=10)
      
  print(f'Termina la evaluación de batchsize: {bs}')
# Out:
# ==========================================================================================
# device:  cuda
# arquitectura: Alexnet
# batch size: 10
# ==========================================================================================
# Epoca: 1/10, Paso: 10/80, Perdida:1.23785
# Precision del modelo en entrenamiento: 53.125 %
# Precision del modelo en validación: 36.0 %
# Epoca: 1/10, Paso: 20/80, Perdida:0.78723
# Precision del modelo en entrenamiento: 51.875 %
# Precision del modelo en validación: 43.5 %
# Epoca: 1/10, Paso: 30/80, Perdida:0.67454
# Precision del modelo en entrenamiento: 51.125 %
# Precision del modelo en validación: 36.5 %
# Epoca: 1/10, Paso: 40/80, Perdida:0.53537
# Precision del modelo en entrenamiento: 54.25 %
# Precision del modelo en validación: 39.5 %
# Epoca: 1/10, Paso: 50/80, Perdida:0.94334
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 44.5 %
# Epoca: 1/10, Paso: 60/80, Perdida:0.93470
# Precision del modelo en entrenamiento: 51.625 %
# Precision del modelo en validación: 40.0 %
# Epoca: 1/10, Paso: 70/80, Perdida:1.16386
# Precision del modelo en entrenamiento: 55.375 %
# Precision del modelo en validación: 43.0 %
# Epoca: 1/10, Paso: 80/80, Perdida:1.11641
# Precision del modelo en entrenamiento: 53.75 %
# Precision del modelo en validación: 44.0 %
# Epoca: 2/10, Paso: 10/80, Perdida:1.67495
# Precision del modelo en entrenamiento: 53.875 %
# Precision del modelo en validación: 40.5 %
# Epoca: 2/10, Paso: 20/80, Perdida:1.41094
# Precision del modelo en entrenamiento: 54.0 %
# Precision del modelo en validación: 41.0 %
# Epoca: 2/10, Paso: 30/80, Perdida:1.97757
# Precision del modelo en entrenamiento: 54.25 %
# Precision del modelo en validación: 44.0 %
# Epoca: 2/10, Paso: 40/80, Perdida:0.79328
# Precision del modelo en entrenamiento: 55.5 %
# Precision del modelo en validación: 33.5 %
# Epoca: 2/10, Paso: 50/80, Perdida:1.06353
# Precision del modelo en entrenamiento: 55.75 %
# Precision del modelo en validación: 47.0 %
# Epoca: 2/10, Paso: 60/80, Perdida:1.34117
# Precision del modelo en entrenamiento: 52.875 %
# Precision del modelo en validación: 34.5 %
# Epoca: 2/10, Paso: 70/80, Perdida:1.92518
# Precision del modelo en entrenamiento: 53.75 %
# Precision del modelo en validación: 41.0 %
# Epoca: 2/10, Paso: 80/80, Perdida:0.90964
# Precision del modelo en entrenamiento: 51.75 %
# Precision del modelo en validación: 44.0 %
# Epoca: 3/10, Paso: 10/80, Perdida:0.96540
# Precision del modelo en entrenamiento: 58.5 %
# Precision del modelo en validación: 46.5 %
# Epoca: 3/10, Paso: 20/80, Perdida:0.40909
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 38.5 %
# Epoca: 3/10, Paso: 30/80, Perdida:1.00764
# Precision del modelo en entrenamiento: 54.5 %
# Precision del modelo en validación: 36.5 %
# Epoca: 3/10, Paso: 40/80, Perdida:0.85177
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 41.5 %
# Epoca: 3/10, Paso: 50/80, Perdida:1.62258
# Precision del modelo en entrenamiento: 56.0 %
# Precision del modelo en validación: 45.5 %
# Epoca: 3/10, Paso: 60/80, Perdida:1.59004
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 48.0 %
# Epoca: 3/10, Paso: 70/80, Perdida:0.87305
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 39.5 %
# Epoca: 3/10, Paso: 80/80, Perdida:1.07770
# Precision del modelo en entrenamiento: 55.875 %
# Precision del modelo en validación: 44.5 %
# Epoca: 4/10, Paso: 10/80, Perdida:1.18829
# Precision del modelo en entrenamiento: 53.5 %
# Precision del modelo en validación: 40.0 %
# Epoca: 4/10, Paso: 20/80, Perdida:1.41974
# Precision del modelo en entrenamiento: 55.125 %
# Precision del modelo en validación: 41.0 %
# Epoca: 4/10, Paso: 30/80, Perdida:1.18605
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 41.5 %
# Epoca: 4/10, Paso: 40/80, Perdida:0.91755
# Precision del modelo en entrenamiento: 53.875 %
# Precision del modelo en validación: 43.5 %
# Epoca: 4/10, Paso: 50/80, Perdida:1.31989
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 44.5 %
# Epoca: 4/10, Paso: 60/80, Perdida:1.00200
# Precision del modelo en entrenamiento: 59.625 %
# Precision del modelo en validación: 42.0 %
# Epoca: 4/10, Paso: 70/80, Perdida:0.71931
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 42.0 %
# Epoca: 4/10, Paso: 80/80, Perdida:1.19098
# Precision del modelo en entrenamiento: 58.5 %
# Precision del modelo en validación: 44.0 %
# Epoca: 5/10, Paso: 10/80, Perdida:1.53756
# Precision del modelo en entrenamiento: 56.625 %
# Precision del modelo en validación: 43.5 %
# Epoca: 5/10, Paso: 20/80, Perdida:0.99016
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 42.5 %
# Epoca: 5/10, Paso: 30/80, Perdida:1.06513
# Precision del modelo en entrenamiento: 57.625 %
# Precision del modelo en validación: 44.5 %
# Epoca: 5/10, Paso: 40/80, Perdida:1.48044
# Precision del modelo en entrenamiento: 56.625 %
# Precision del modelo en validación: 35.0 %
# Epoca: 5/10, Paso: 50/80, Perdida:1.36062
# Precision del modelo en entrenamiento: 56.0 %
# Precision del modelo en validación: 43.0 %
# Epoca: 5/10, Paso: 60/80, Perdida:0.95170
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 43.5 %
# Epoca: 5/10, Paso: 70/80, Perdida:0.97639
# Precision del modelo en entrenamiento: 60.875 %
# Precision del modelo en validación: 44.0 %
# Epoca: 5/10, Paso: 80/80, Perdida:1.40682
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 41.0 %
# Epoca: 6/10, Paso: 10/80, Perdida:0.91360
# Precision del modelo en entrenamiento: 58.5 %
# Precision del modelo en validación: 48.0 %
# Epoca: 6/10, Paso: 20/80, Perdida:1.36043
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 43.0 %
# Epoca: 6/10, Paso: 30/80, Perdida:1.47390
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 42.5 %
# Epoca: 6/10, Paso: 40/80, Perdida:1.53520
# Precision del modelo en entrenamiento: 58.875 %
# Precision del modelo en validación: 40.5 %
# Epoca: 6/10, Paso: 50/80, Perdida:0.85032
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 42.0 %
# Epoca: 6/10, Paso: 60/80, Perdida:0.90826
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 43.5 %
# Epoca: 6/10, Paso: 70/80, Perdida:0.99001
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 42.0 %
# Epoca: 6/10, Paso: 80/80, Perdida:0.94954
# Precision del modelo en entrenamiento: 56.375 %
# Precision del modelo en validación: 44.0 %
# Epoca: 7/10, Paso: 10/80, Perdida:1.38294
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 39.0 %
# Epoca: 7/10, Paso: 20/80, Perdida:1.25264
# Precision del modelo en entrenamiento: 57.875 %
# Precision del modelo en validación: 46.0 %
# Epoca: 7/10, Paso: 30/80, Perdida:0.63152
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 42.5 %
# Epoca: 7/10, Paso: 40/80, Perdida:0.82123
# Precision del modelo en entrenamiento: 61.5 %
# Precision del modelo en validación: 41.5 %
# Epoca: 7/10, Paso: 50/80, Perdida:0.51068
# Precision del modelo en entrenamiento: 59.625 %
# Precision del modelo en validación: 43.5 %
# Epoca: 7/10, Paso: 60/80, Perdida:1.47919
# Precision del modelo en entrenamiento: 56.375 %
# Precision del modelo en validación: 38.5 %
# Epoca: 7/10, Paso: 70/80, Perdida:1.54968
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 41.0 %
# Epoca: 7/10, Paso: 80/80, Perdida:0.52323
# Precision del modelo en entrenamiento: 59.375 %
# Precision del modelo en validación: 41.0 %
# Epoca: 8/10, Paso: 10/80, Perdida:0.92901
# Precision del modelo en entrenamiento: 55.375 %
# Precision del modelo en validación: 46.0 %
# Epoca: 8/10, Paso: 20/80, Perdida:1.23214
# Precision del modelo en entrenamiento: 62.0 %
# Precision del modelo en validación: 43.5 %
# Epoca: 8/10, Paso: 30/80, Perdida:1.34471
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 46.5 %
# Epoca: 8/10, Paso: 40/80, Perdida:0.85040
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 41.5 %
# Epoca: 8/10, Paso: 50/80, Perdida:0.85336
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 44.0 %
# Epoca: 8/10, Paso: 60/80, Perdida:1.10376
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 41.5 %
# Epoca: 8/10, Paso: 70/80, Perdida:0.88941
# Precision del modelo en entrenamiento: 59.625 %
# Precision del modelo en validación: 43.0 %
# Epoca: 8/10, Paso: 80/80, Perdida:1.26397
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 42.0 %
# Epoca: 9/10, Paso: 10/80, Perdida:1.78579
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 44.0 %
# Epoca: 9/10, Paso: 20/80, Perdida:1.36521
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 44.0 %
# Epoca: 9/10, Paso: 30/80, Perdida:1.68460
# Precision del modelo en entrenamiento: 59.125 %
# Precision del modelo en validación: 46.0 %
# Epoca: 9/10, Paso: 40/80, Perdida:1.05729
# Precision del modelo en entrenamiento: 58.875 %
# Precision del modelo en validación: 47.0 %
# Epoca: 9/10, Paso: 50/80, Perdida:1.17933
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 48.0 %
# Epoca: 9/10, Paso: 60/80, Perdida:0.88607
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 46.0 %
# Epoca: 9/10, Paso: 70/80, Perdida:1.62999
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 42.0 %
# Epoca: 9/10, Paso: 80/80, Perdida:1.18222
# Precision del modelo en entrenamiento: 58.5 %
# Precision del modelo en validación: 48.5 %
# Epoca: 10/10, Paso: 10/80, Perdida:1.65032
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 44.0 %
# Epoca: 10/10, Paso: 20/80, Perdida:0.72343
# Precision del modelo en entrenamiento: 56.375 %
# Precision del modelo en validación: 43.5 %
# Epoca: 10/10, Paso: 30/80, Perdida:1.93127
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 45.0 %
# Epoca: 10/10, Paso: 40/80, Perdida:0.65597
# Precision del modelo en entrenamiento: 61.5 %
# Precision del modelo en validación: 44.0 %
# Epoca: 10/10, Paso: 50/80, Perdida:1.15976
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 39.0 %
# Epoca: 10/10, Paso: 60/80, Perdida:1.13995
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 41.5 %
# Epoca: 10/10, Paso: 70/80, Perdida:1.24586
# Precision del modelo en entrenamiento: 59.75 %
# Precision del modelo en validación: 44.5 %
# Epoca: 10/10, Paso: 80/80, Perdida:0.70253
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 45.0 %
# Termina la evaluación de batchsize: 10
# ==========================================================================================
# device:  cuda
# arquitectura: resnet18
# batch size: 10
# ==========================================================================================
# Epoca: 1/10, Paso: 10/80, Perdida:2.10581
# Precision del modelo en entrenamiento: 28.375 %
# Precision del modelo en validación: 10.0 %
# Epoca: 1/10, Paso: 20/80, Perdida:1.93142
# Precision del modelo en entrenamiento: 31.375 %
# Precision del modelo en validación: 10.0 %
# Epoca: 1/10, Paso: 30/80, Perdida:1.65091
# Precision del modelo en entrenamiento: 39.75 %
# Precision del modelo en validación: 10.5 %
# Epoca: 1/10, Paso: 40/80, Perdida:1.39565
# Precision del modelo en entrenamiento: 32.625 %
# Precision del modelo en validación: 9.5 %
# Epoca: 1/10, Paso: 50/80, Perdida:2.55359
# Precision del modelo en entrenamiento: 33.375 %
# Precision del modelo en validación: 11.0 %
# Epoca: 1/10, Paso: 60/80, Perdida:1.52099
# Precision del modelo en entrenamiento: 42.5 %
# Precision del modelo en validación: 13.0 %
# Epoca: 1/10, Paso: 70/80, Perdida:1.86185
# Precision del modelo en entrenamiento: 39.75 %
# Precision del modelo en validación: 13.5 %
# Epoca: 1/10, Paso: 80/80, Perdida:1.62111
# Precision del modelo en entrenamiento: 40.625 %
# Precision del modelo en validación: 9.5 %
# Epoca: 2/10, Paso: 10/80, Perdida:1.66201
# Precision del modelo en entrenamiento: 44.875 %
# Precision del modelo en validación: 10.5 %
# Epoca: 2/10, Paso: 20/80, Perdida:1.46880
# Precision del modelo en entrenamiento: 44.875 %
# Precision del modelo en validación: 13.0 %
# Epoca: 2/10, Paso: 30/80, Perdida:2.00800
# Precision del modelo en entrenamiento: 45.0 %
# Precision del modelo en validación: 12.5 %
# Epoca: 2/10, Paso: 40/80, Perdida:1.52777
# Precision del modelo en entrenamiento: 47.25 %
# Precision del modelo en validación: 11.0 %
# Epoca: 2/10, Paso: 50/80, Perdida:1.17684
# Precision del modelo en entrenamiento: 45.0 %
# Precision del modelo en validación: 9.5 %
# Epoca: 2/10, Paso: 60/80, Perdida:1.66969
# Precision del modelo en entrenamiento: 46.875 %
# Precision del modelo en validación: 11.0 %
# Epoca: 2/10, Paso: 70/80, Perdida:1.89088
# Precision del modelo en entrenamiento: 48.25 %
# Precision del modelo en validación: 12.5 %
# Epoca: 2/10, Paso: 80/80, Perdida:1.61339
# Precision del modelo en entrenamiento: 48.125 %
# Precision del modelo en validación: 13.0 %
# Epoca: 3/10, Paso: 10/80, Perdida:1.34957
# Precision del modelo en entrenamiento: 49.75 %
# Precision del modelo en validación: 13.0 %
# Epoca: 3/10, Paso: 20/80, Perdida:1.16956
# Precision del modelo en entrenamiento: 49.75 %
# Precision del modelo en validación: 11.5 %
# Epoca: 3/10, Paso: 30/80, Perdida:1.39221
# Precision del modelo en entrenamiento: 53.125 %
# Precision del modelo en validación: 12.0 %
# Epoca: 3/10, Paso: 40/80, Perdida:1.12016
# Precision del modelo en entrenamiento: 48.0 %
# Precision del modelo en validación: 14.0 %
# Epoca: 3/10, Paso: 50/80, Perdida:1.72769
# Precision del modelo en entrenamiento: 51.75 %
# Precision del modelo en validación: 11.5 %
# Epoca: 3/10, Paso: 60/80, Perdida:1.27443
# Precision del modelo en entrenamiento: 53.0 %
# Precision del modelo en validación: 12.0 %
# Epoca: 3/10, Paso: 70/80, Perdida:1.35226
# Precision del modelo en entrenamiento: 52.125 %
# Precision del modelo en validación: 11.5 %
# Epoca: 3/10, Paso: 80/80, Perdida:1.56408
# Precision del modelo en entrenamiento: 50.375 %
# Precision del modelo en validación: 9.5 %
# Epoca: 4/10, Paso: 10/80, Perdida:1.53632
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 11.0 %
# Epoca: 4/10, Paso: 20/80, Perdida:1.66968
# Precision del modelo en entrenamiento: 56.125 %
# Precision del modelo en validación: 13.5 %
# Epoca: 4/10, Paso: 30/80, Perdida:1.51102
# Precision del modelo en entrenamiento: 52.625 %
# Precision del modelo en validación: 13.0 %
# Epoca: 4/10, Paso: 40/80, Perdida:1.38724
# Precision del modelo en entrenamiento: 52.25 %
# Precision del modelo en validación: 11.5 %
# Epoca: 4/10, Paso: 50/80, Perdida:1.30364
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 13.0 %
# Epoca: 4/10, Paso: 60/80, Perdida:1.07781
# Precision del modelo en entrenamiento: 52.875 %
# Precision del modelo en validación: 13.0 %
# Epoca: 4/10, Paso: 70/80, Perdida:1.11742
# Precision del modelo en entrenamiento: 53.625 %
# Precision del modelo en validación: 13.5 %
# Epoca: 4/10, Paso: 80/80, Perdida:1.56783
# Precision del modelo en entrenamiento: 50.25 %
# Precision del modelo en validación: 13.5 %
# Epoca: 5/10, Paso: 10/80, Perdida:1.56939
# Precision del modelo en entrenamiento: 54.375 %
# Precision del modelo en validación: 13.0 %
# Epoca: 5/10, Paso: 20/80, Perdida:1.48563
# Precision del modelo en entrenamiento: 54.375 %
# Precision del modelo en validación: 12.5 %
# Epoca: 5/10, Paso: 30/80, Perdida:1.69235
# Precision del modelo en entrenamiento: 52.125 %
# Precision del modelo en validación: 12.0 %
# Epoca: 5/10, Paso: 40/80, Perdida:1.26996
# Precision del modelo en entrenamiento: 54.25 %
# Precision del modelo en validación: 11.5 %
# Epoca: 5/10, Paso: 50/80, Perdida:1.66229
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 14.0 %
# Epoca: 5/10, Paso: 60/80, Perdida:1.59213
# Precision del modelo en entrenamiento: 55.125 %
# Precision del modelo en validación: 13.5 %
# Epoca: 5/10, Paso: 70/80, Perdida:1.20869
# Precision del modelo en entrenamiento: 52.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 5/10, Paso: 80/80, Perdida:1.31473
# Precision del modelo en entrenamiento: 53.625 %
# Precision del modelo en validación: 15.5 %
# Epoca: 6/10, Paso: 10/80, Perdida:1.26396
# Precision del modelo en entrenamiento: 54.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 6/10, Paso: 20/80, Perdida:1.25028
# Precision del modelo en entrenamiento: 54.125 %
# Precision del modelo en validación: 13.5 %
# Epoca: 6/10, Paso: 30/80, Perdida:1.95743
# Precision del modelo en entrenamiento: 53.875 %
# Precision del modelo en validación: 15.5 %
# Epoca: 6/10, Paso: 40/80, Perdida:1.83476
# Precision del modelo en entrenamiento: 55.375 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 50/80, Perdida:1.45357
# Precision del modelo en entrenamiento: 51.5 %
# Precision del modelo en validación: 13.0 %
# Epoca: 6/10, Paso: 60/80, Perdida:1.32487
# Precision del modelo en entrenamiento: 54.75 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 70/80, Perdida:1.39168
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 13.0 %
# Epoca: 6/10, Paso: 80/80, Perdida:1.53549
# Precision del modelo en entrenamiento: 55.25 %
# Precision del modelo en validación: 13.5 %
# Epoca: 7/10, Paso: 10/80, Perdida:1.44639
# Precision del modelo en entrenamiento: 55.125 %
# Precision del modelo en validación: 11.5 %
# Epoca: 7/10, Paso: 20/80, Perdida:1.73938
# Precision del modelo en entrenamiento: 55.125 %
# Precision del modelo en validación: 11.5 %
# Epoca: 7/10, Paso: 30/80, Perdida:1.23589
# Precision del modelo en entrenamiento: 52.625 %
# Precision del modelo en validación: 12.0 %
# Epoca: 7/10, Paso: 40/80, Perdida:1.27255
# Precision del modelo en entrenamiento: 56.875 %
# Precision del modelo en validación: 13.0 %
# Epoca: 7/10, Paso: 50/80, Perdida:1.23855
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 13.0 %
# Epoca: 7/10, Paso: 60/80, Perdida:1.44422
# Precision del modelo en entrenamiento: 56.625 %
# Precision del modelo en validación: 13.5 %
# Epoca: 7/10, Paso: 70/80, Perdida:1.65074
# Precision del modelo en entrenamiento: 54.125 %
# Precision del modelo en validación: 12.5 %
# Epoca: 7/10, Paso: 80/80, Perdida:1.07724
# Precision del modelo en entrenamiento: 55.875 %
# Precision del modelo en validación: 12.5 %
# Epoca: 8/10, Paso: 10/80, Perdida:0.97239
# Precision del modelo en entrenamiento: 54.375 %
# Precision del modelo en validación: 13.0 %
# Epoca: 8/10, Paso: 20/80, Perdida:1.39686
# Precision del modelo en entrenamiento: 55.625 %
# Precision del modelo en validación: 12.5 %
# Epoca: 8/10, Paso: 30/80, Perdida:1.38680
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 13.5 %
# Epoca: 8/10, Paso: 40/80, Perdida:1.46247
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 13.5 %
# Epoca: 8/10, Paso: 50/80, Perdida:1.48933
# Precision del modelo en entrenamiento: 52.75 %
# Precision del modelo en validación: 13.5 %
# Epoca: 8/10, Paso: 60/80, Perdida:1.33266
# Precision del modelo en entrenamiento: 55.75 %
# Precision del modelo en validación: 14.0 %
# Epoca: 8/10, Paso: 70/80, Perdida:1.45817
# Precision del modelo en entrenamiento: 55.375 %
# Precision del modelo en validación: 13.5 %
# Epoca: 8/10, Paso: 80/80, Perdida:1.46896
# Precision del modelo en entrenamiento: 53.875 %
# Precision del modelo en validación: 14.0 %
# Epoca: 9/10, Paso: 10/80, Perdida:1.20883
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 20/80, Perdida:1.00665
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 30/80, Perdida:1.53641
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 14.0 %
# Epoca: 9/10, Paso: 40/80, Perdida:1.48166
# Precision del modelo en entrenamiento: 54.0 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 50/80, Perdida:1.17918
# Precision del modelo en entrenamiento: 50.75 %
# Precision del modelo en validación: 14.0 %
# Epoca: 9/10, Paso: 60/80, Perdida:1.54459
# Precision del modelo en entrenamiento: 52.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 70/80, Perdida:1.84813
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 14.0 %
# Epoca: 9/10, Paso: 80/80, Perdida:1.42767
# Precision del modelo en entrenamiento: 53.5 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 10/80, Perdida:1.58518
# Precision del modelo en entrenamiento: 53.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 20/80, Perdida:1.17236
# Precision del modelo en entrenamiento: 56.5 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 30/80, Perdida:1.21353
# Precision del modelo en entrenamiento: 54.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 40/80, Perdida:1.16806
# Precision del modelo en entrenamiento: 54.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 50/80, Perdida:1.22591
# Precision del modelo en entrenamiento: 56.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 60/80, Perdida:1.85874
# Precision del modelo en entrenamiento: 56.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 70/80, Perdida:2.02453
# Precision del modelo en entrenamiento: 52.25 %
# Precision del modelo en validación: 15.5 %
# Epoca: 10/10, Paso: 80/80, Perdida:1.36762
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 15.0 %
# Termina la evaluación de batchsize: 10
# ==========================================================================================
# device:  cuda
# arquitectura: vgg11_bn
# batch size: 10
# ==========================================================================================
# Epoca: 1/10, Paso: 10/80, Perdida:2.18621
# Precision del modelo en entrenamiento: 21.5 %
# Precision del modelo en validación: 13.5 %
# Epoca: 1/10, Paso: 20/80, Perdida:1.64587
# Precision del modelo en entrenamiento: 32.875 %
# Precision del modelo en validación: 12.0 %
# Epoca: 1/10, Paso: 30/80, Perdida:1.89903
# Precision del modelo en entrenamiento: 40.25 %
# Precision del modelo en validación: 13.0 %
# Epoca: 1/10, Paso: 40/80, Perdida:1.43047
# Precision del modelo en entrenamiento: 35.875 %
# Precision del modelo en validación: 13.0 %
# Epoca: 1/10, Paso: 50/80, Perdida:1.83479
# Precision del modelo en entrenamiento: 43.5 %
# Precision del modelo en validación: 10.5 %
# Epoca: 1/10, Paso: 60/80, Perdida:1.36611
# Precision del modelo en entrenamiento: 45.625 %
# Precision del modelo en validación: 12.5 %
# Epoca: 1/10, Paso: 70/80, Perdida:1.51487
# Precision del modelo en entrenamiento: 47.25 %
# Precision del modelo en validación: 13.5 %
# Epoca: 1/10, Paso: 80/80, Perdida:1.54190
# Precision del modelo en entrenamiento: 46.5 %
# Precision del modelo en validación: 11.5 %
# Epoca: 2/10, Paso: 10/80, Perdida:1.73060
# Precision del modelo en entrenamiento: 51.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 2/10, Paso: 20/80, Perdida:1.33507
# Precision del modelo en entrenamiento: 52.5 %
# Precision del modelo en validación: 14.5 %
# Epoca: 2/10, Paso: 30/80, Perdida:1.68885
# Precision del modelo en entrenamiento: 50.75 %
# Precision del modelo en validación: 13.5 %
# Epoca: 2/10, Paso: 40/80, Perdida:1.02803
# Precision del modelo en entrenamiento: 48.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 2/10, Paso: 50/80, Perdida:1.21543
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 12.5 %
# Epoca: 2/10, Paso: 60/80, Perdida:1.59458
# Precision del modelo en entrenamiento: 51.875 %
# Precision del modelo en validación: 10.5 %
# Epoca: 2/10, Paso: 70/80, Perdida:1.53560
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 16.0 %
# Epoca: 2/10, Paso: 80/80, Perdida:0.93761
# Precision del modelo en entrenamiento: 53.5 %
# Precision del modelo en validación: 13.5 %
# Epoca: 3/10, Paso: 10/80, Perdida:1.13905
# Precision del modelo en entrenamiento: 54.375 %
# Precision del modelo en validación: 14.0 %
# Epoca: 3/10, Paso: 20/80, Perdida:0.98286
# Precision del modelo en entrenamiento: 52.625 %
# Precision del modelo en validación: 16.0 %
# Epoca: 3/10, Paso: 30/80, Perdida:1.59103
# Precision del modelo en entrenamiento: 52.875 %
# Precision del modelo en validación: 16.0 %
# Epoca: 3/10, Paso: 40/80, Perdida:0.98688
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 15.0 %
# Epoca: 3/10, Paso: 50/80, Perdida:1.28138
# Precision del modelo en entrenamiento: 56.25 %
# Precision del modelo en validación: 16.0 %
# Epoca: 3/10, Paso: 60/80, Perdida:1.22666
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 16.5 %
# Epoca: 3/10, Paso: 70/80, Perdida:1.42661
# Precision del modelo en entrenamiento: 54.75 %
# Precision del modelo en validación: 14.0 %
# Epoca: 3/10, Paso: 80/80, Perdida:1.54993
# Precision del modelo en entrenamiento: 53.625 %
# Precision del modelo en validación: 17.0 %
# Epoca: 4/10, Paso: 10/80, Perdida:1.20602
# Precision del modelo en entrenamiento: 55.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 4/10, Paso: 20/80, Perdida:1.42757
# Precision del modelo en entrenamiento: 57.625 %
# Precision del modelo en validación: 13.0 %
# Epoca: 4/10, Paso: 30/80, Perdida:1.19730
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 15.5 %
# Epoca: 4/10, Paso: 40/80, Perdida:0.87235
# Precision del modelo en entrenamiento: 57.625 %
# Precision del modelo en validación: 17.0 %
# Epoca: 4/10, Paso: 50/80, Perdida:1.41756
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 15.5 %
# Epoca: 4/10, Paso: 60/80, Perdida:0.67381
# Precision del modelo en entrenamiento: 56.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 4/10, Paso: 70/80, Perdida:1.32660
# Precision del modelo en entrenamiento: 60.125 %
# Precision del modelo en validación: 16.0 %
# Epoca: 4/10, Paso: 80/80, Perdida:1.00083
# Precision del modelo en entrenamiento: 54.125 %
# Precision del modelo en validación: 14.0 %
# Epoca: 5/10, Paso: 10/80, Perdida:1.28933
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 15.0 %
# Epoca: 5/10, Paso: 20/80, Perdida:1.00309
# Precision del modelo en entrenamiento: 54.875 %
# Precision del modelo en validación: 17.0 %
# Epoca: 5/10, Paso: 30/80, Perdida:1.56686
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 13.5 %
# Epoca: 5/10, Paso: 40/80, Perdida:1.20722
# Precision del modelo en entrenamiento: 56.0 %
# Precision del modelo en validación: 15.5 %
# Epoca: 5/10, Paso: 50/80, Perdida:1.50467
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 16.0 %
# Epoca: 5/10, Paso: 60/80, Perdida:1.20268
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 5/10, Paso: 70/80, Perdida:1.13058
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 5/10, Paso: 80/80, Perdida:1.24566
# Precision del modelo en entrenamiento: 56.125 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 10/80, Perdida:1.03099
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 16.5 %
# Epoca: 6/10, Paso: 20/80, Perdida:1.87063
# Precision del modelo en entrenamiento: 57.125 %
# Precision del modelo en validación: 17.0 %
# Epoca: 6/10, Paso: 30/80, Perdida:1.40491
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 20.5 %
# Epoca: 6/10, Paso: 40/80, Perdida:1.63475
# Precision del modelo en entrenamiento: 55.875 %
# Precision del modelo en validación: 12.5 %
# Epoca: 6/10, Paso: 50/80, Perdida:1.52659
# Precision del modelo en entrenamiento: 58.125 %
# Precision del modelo en validación: 11.5 %
# Epoca: 6/10, Paso: 60/80, Perdida:1.21776
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 70/80, Perdida:1.30343
# Precision del modelo en entrenamiento: 58.875 %
# Precision del modelo en validación: 14.5 %
# Epoca: 6/10, Paso: 80/80, Perdida:1.34956
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 12.0 %
# Epoca: 7/10, Paso: 10/80, Perdida:1.34818
# Precision del modelo en entrenamiento: 57.125 %
# Precision del modelo en validación: 15.5 %
# Epoca: 7/10, Paso: 20/80, Perdida:1.24798
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 15.5 %
# Epoca: 7/10, Paso: 30/80, Perdida:1.22608
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 13.5 %
# Epoca: 7/10, Paso: 40/80, Perdida:1.16838
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 12.0 %
# Epoca: 7/10, Paso: 50/80, Perdida:1.40659
# Precision del modelo en entrenamiento: 57.875 %
# Precision del modelo en validación: 17.0 %
# Epoca: 7/10, Paso: 60/80, Perdida:0.99734
# Precision del modelo en entrenamiento: 59.75 %
# Precision del modelo en validación: 17.0 %
# Epoca: 7/10, Paso: 70/80, Perdida:1.58143
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 15.5 %
# Epoca: 7/10, Paso: 80/80, Perdida:0.97793
# Precision del modelo en entrenamiento: 59.25 %
# Precision del modelo en validación: 13.5 %
# Epoca: 8/10, Paso: 10/80, Perdida:0.88207
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 13.5 %
# Epoca: 8/10, Paso: 20/80, Perdida:1.34455
# Precision del modelo en entrenamiento: 58.125 %
# Precision del modelo en validación: 16.0 %
# Epoca: 8/10, Paso: 30/80, Perdida:1.67288
# Precision del modelo en entrenamiento: 58.5 %
# Precision del modelo en validación: 16.5 %
# Epoca: 8/10, Paso: 40/80, Perdida:0.88962
# Precision del modelo en entrenamiento: 58.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 8/10, Paso: 50/80, Perdida:1.26619
# Precision del modelo en entrenamiento: 60.125 %
# Precision del modelo en validación: 14.0 %
# Epoca: 8/10, Paso: 60/80, Perdida:0.94760
# Precision del modelo en entrenamiento: 57.625 %
# Precision del modelo en validación: 13.5 %
# Epoca: 8/10, Paso: 70/80, Perdida:1.31571
# Precision del modelo en entrenamiento: 62.0 %
# Precision del modelo en validación: 14.0 %
# Epoca: 8/10, Paso: 80/80, Perdida:1.19639
# Precision del modelo en entrenamiento: 60.375 %
# Precision del modelo en validación: 16.0 %
# Epoca: 9/10, Paso: 10/80, Perdida:1.34494
# Precision del modelo en entrenamiento: 60.0 %
# Precision del modelo en validación: 15.5 %
# Epoca: 9/10, Paso: 20/80, Perdida:1.30251
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 30/80, Perdida:1.51804
# Precision del modelo en entrenamiento: 59.125 %
# Precision del modelo en validación: 16.5 %
# Epoca: 9/10, Paso: 40/80, Perdida:1.31954
# Precision del modelo en entrenamiento: 59.375 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 50/80, Perdida:1.16326
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 17.0 %
# Epoca: 9/10, Paso: 60/80, Perdida:1.33750
# Precision del modelo en entrenamiento: 59.375 %
# Precision del modelo en validación: 16.5 %
# Epoca: 9/10, Paso: 70/80, Perdida:1.53279
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 80/80, Perdida:1.41851
# Precision del modelo en entrenamiento: 60.5 %
# Precision del modelo en validación: 16.5 %
# Epoca: 10/10, Paso: 10/80, Perdida:1.66909
# Precision del modelo en entrenamiento: 60.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 20/80, Perdida:0.97225
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 13.0 %
# Epoca: 10/10, Paso: 30/80, Perdida:1.11888
# Precision del modelo en entrenamiento: 60.0 %
# Precision del modelo en validación: 17.0 %
# Epoca: 10/10, Paso: 40/80, Perdida:1.08303
# Precision del modelo en entrenamiento: 60.0 %
# Precision del modelo en validación: 15.5 %
# Epoca: 10/10, Paso: 50/80, Perdida:1.15396
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 60/80, Perdida:1.85505
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 13.0 %
# Epoca: 10/10, Paso: 70/80, Perdida:2.02606
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 80/80, Perdida:0.79343
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 13.5 %
# Termina la evaluación de batchsize: 10
# ==========================================================================================
# device:  cuda
# arquitectura: densenet121
# ==========================================================================================
# Epoca: 1/10, Paso: 10/80, Perdida:2.25838
# Precision del modelo en entrenamiento: 13.125 %
# Precision del modelo en validación: 12.5 %
# Epoca: 1/10, Paso: 20/80, Perdida:2.11397
# Precision del modelo en entrenamiento: 21.875 %
# Precision del modelo en validación: 10.0 %
# Epoca: 1/10, Paso: 30/80, Perdida:1.91752
# Precision del modelo en entrenamiento: 33.375 %
# Precision del modelo en validación: 8.5 %
# Epoca: 1/10, Paso: 40/80, Perdida:1.61870
# Precision del modelo en entrenamiento: 29.875 %
# Precision del modelo en validación: 11.5 %
# Epoca: 1/10, Paso: 50/80, Perdida:2.13357
# Precision del modelo en entrenamiento: 32.25 %
# Precision del modelo en validación: 10.5 %
# Epoca: 1/10, Paso: 60/80, Perdida:1.63894
# Precision del modelo en entrenamiento: 40.375 %
# Precision del modelo en validación: 10.0 %
# Epoca: 1/10, Paso: 70/80, Perdida:1.94524
# Precision del modelo en entrenamiento: 37.5 %
# Precision del modelo en validación: 11.0 %
# Epoca: 1/10, Paso: 80/80, Perdida:1.76587
# Precision del modelo en entrenamiento: 42.75 %
# Precision del modelo en validación: 11.5 %
# Epoca: 2/10, Paso: 10/80, Perdida:1.89081
# Precision del modelo en entrenamiento: 47.625 %
# Precision del modelo en validación: 10.5 %
# Epoca: 2/10, Paso: 20/80, Perdida:1.46680
# Precision del modelo en entrenamiento: 44.0 %
# Precision del modelo en validación: 13.0 %
# Epoca: 2/10, Paso: 30/80, Perdida:1.90018
# Precision del modelo en entrenamiento: 47.375 %
# Precision del modelo en validación: 13.5 %
# Epoca: 2/10, Paso: 40/80, Perdida:1.75446
# Precision del modelo en entrenamiento: 49.75 %
# Precision del modelo en validación: 10.5 %
# Epoca: 2/10, Paso: 50/80, Perdida:1.24282
# Precision del modelo en entrenamiento: 43.75 %
# Precision del modelo en validación: 10.0 %
# Epoca: 2/10, Paso: 60/80, Perdida:1.81888
# Precision del modelo en entrenamiento: 48.25 %
# Precision del modelo en validación: 11.0 %
# Epoca: 2/10, Paso: 70/80, Perdida:2.06955
# Precision del modelo en entrenamiento: 49.625 %
# Precision del modelo en validación: 9.5 %
# Epoca: 2/10, Paso: 80/80, Perdida:1.66634
# Precision del modelo en entrenamiento: 47.125 %
# Precision del modelo en validación: 10.0 %
# Epoca: 3/10, Paso: 10/80, Perdida:1.39519
# Precision del modelo en entrenamiento: 51.5 %
# Precision del modelo en validación: 11.5 %
# Epoca: 3/10, Paso: 20/80, Perdida:1.33590
# Precision del modelo en entrenamiento: 52.375 %
# Precision del modelo en validación: 10.0 %
# Epoca: 3/10, Paso: 30/80, Perdida:1.39828
# Precision del modelo en entrenamiento: 53.625 %
# Precision del modelo en validación: 13.0 %
# Epoca: 3/10, Paso: 40/80, Perdida:1.31261
# Precision del modelo en entrenamiento: 51.625 %
# Precision del modelo en validación: 11.0 %
# Epoca: 3/10, Paso: 50/80, Perdida:1.69083
# Precision del modelo en entrenamiento: 53.0 %
# Precision del modelo en validación: 11.5 %
# Epoca: 3/10, Paso: 60/80, Perdida:1.26633
# Precision del modelo en entrenamiento: 52.875 %
# Precision del modelo en validación: 12.0 %
# Epoca: 3/10, Paso: 70/80, Perdida:1.38983
# Precision del modelo en entrenamiento: 49.375 %
# Precision del modelo en validación: 10.0 %
# Epoca: 3/10, Paso: 80/80, Perdida:1.47964
# Precision del modelo en entrenamiento: 53.5 %
# Precision del modelo en validación: 11.0 %
# Epoca: 4/10, Paso: 10/80, Perdida:1.75567
# Precision del modelo en entrenamiento: 54.125 %
# Precision del modelo en validación: 12.0 %
# Epoca: 4/10, Paso: 20/80, Perdida:1.61169
# Precision del modelo en entrenamiento: 53.5 %
# Precision del modelo en validación: 12.5 %
# Epoca: 4/10, Paso: 30/80, Perdida:1.41037
# Precision del modelo en entrenamiento: 55.375 %
# Precision del modelo en validación: 13.0 %
# Epoca: 4/10, Paso: 40/80, Perdida:1.41424
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 14.5 %
# Epoca: 4/10, Paso: 50/80, Perdida:1.47112
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 14.5 %
# Epoca: 4/10, Paso: 60/80, Perdida:0.97769
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 13.0 %
# Epoca: 4/10, Paso: 70/80, Perdida:1.24686
# Precision del modelo en entrenamiento: 56.125 %
# Precision del modelo en validación: 10.0 %
# Epoca: 4/10, Paso: 80/80, Perdida:1.65872
# Precision del modelo en entrenamiento: 52.25 %
# Precision del modelo en validación: 13.0 %
# Epoca: 5/10, Paso: 10/80, Perdida:1.54103
# Precision del modelo en entrenamiento: 55.25 %
# Precision del modelo en validación: 12.5 %
# Epoca: 5/10, Paso: 20/80, Perdida:1.26536
# Precision del modelo en entrenamiento: 54.0 %
# Precision del modelo en validación: 11.5 %
# Epoca: 5/10, Paso: 30/80, Perdida:1.81858
# Precision del modelo en entrenamiento: 53.75 %
# Precision del modelo en validación: 9.5 %
# Epoca: 5/10, Paso: 40/80, Perdida:1.39652
# Precision del modelo en entrenamiento: 57.625 %
# Precision del modelo en validación: 10.5 %
# Epoca: 5/10, Paso: 50/80, Perdida:1.32622
# Precision del modelo en entrenamiento: 54.625 %
# Precision del modelo en validación: 12.0 %
# Epoca: 5/10, Paso: 60/80, Perdida:1.45661
# Precision del modelo en entrenamiento: 55.875 %
# Precision del modelo en validación: 12.5 %
# Epoca: 5/10, Paso: 70/80, Perdida:1.45402
# Precision del modelo en entrenamiento: 55.875 %
# Precision del modelo en validación: 13.0 %
# Epoca: 5/10, Paso: 80/80, Perdida:1.47013
# Precision del modelo en entrenamiento: 56.125 %
# Precision del modelo en validación: 12.5 %
# Epoca: 6/10, Paso: 10/80, Perdida:1.37386
# Precision del modelo en entrenamiento: 56.5 %
# Precision del modelo en validación: 13.0 %
# Epoca: 6/10, Paso: 20/80, Perdida:1.11080
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 12.5 %
# Epoca: 6/10, Paso: 30/80, Perdida:1.76569
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 13.5 %
# Epoca: 6/10, Paso: 40/80, Perdida:1.64723
# Precision del modelo en entrenamiento: 56.625 %
# Precision del modelo en validación: 14.5 %
# Epoca: 6/10, Paso: 50/80, Perdida:1.31023
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 60/80, Perdida:1.27141
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 13.5 %
# Epoca: 6/10, Paso: 70/80, Perdida:1.34360
# Precision del modelo en entrenamiento: 58.875 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 80/80, Perdida:1.37704
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 12.5 %
# Epoca: 7/10, Paso: 10/80, Perdida:1.50287
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 11.5 %
# Epoca: 7/10, Paso: 20/80, Perdida:1.69336
# Precision del modelo en entrenamiento: 55.5 %
# Precision del modelo en validación: 12.0 %
# Epoca: 7/10, Paso: 30/80, Perdida:1.42604
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 12.5 %
# Epoca: 7/10, Paso: 40/80, Perdida:1.38607
# Precision del modelo en entrenamiento: 55.75 %
# Precision del modelo en validación: 13.5 %
# Epoca: 7/10, Paso: 50/80, Perdida:1.20611
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 13.5 %
# Epoca: 7/10, Paso: 60/80, Perdida:1.31906
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 14.0 %
# Epoca: 7/10, Paso: 70/80, Perdida:1.47231
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 14.0 %
# Epoca: 7/10, Paso: 80/80, Perdida:1.16446
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 13.0 %
# Epoca: 8/10, Paso: 10/80, Perdida:1.41486
# Precision del modelo en entrenamiento: 57.625 %
# Precision del modelo en validación: 14.0 %
# Epoca: 8/10, Paso: 20/80, Perdida:1.41325
# Precision del modelo en entrenamiento: 55.125 %
# Precision del modelo en validación: 16.0 %
# Epoca: 8/10, Paso: 30/80, Perdida:1.37305
# Precision del modelo en entrenamiento: 57.125 %
# Precision del modelo en validación: 14.5 %
# Epoca: 8/10, Paso: 40/80, Perdida:1.20350
# Precision del modelo en entrenamiento: 55.125 %
# Precision del modelo en validación: 15.5 %
# Epoca: 8/10, Paso: 50/80, Perdida:1.42097
# Precision del modelo en entrenamiento: 56.625 %
# Precision del modelo en validación: 14.5 %
# Epoca: 8/10, Paso: 60/80, Perdida:1.67448
# Precision del modelo en entrenamiento: 55.5 %
# Precision del modelo en validación: 13.0 %
# Epoca: 8/10, Paso: 70/80, Perdida:1.40435
# Precision del modelo en entrenamiento: 57.625 %
# Precision del modelo en validación: 14.0 %
# Epoca: 8/10, Paso: 80/80, Perdida:1.20467
# Precision del modelo en entrenamiento: 56.5 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 10/80, Perdida:1.40747
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 20/80, Perdida:1.11860
# Precision del modelo en entrenamiento: 55.375 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 30/80, Perdida:1.68024
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 13.5 %
# Epoca: 9/10, Paso: 40/80, Perdida:1.64991
# Precision del modelo en entrenamiento: 56.625 %
# Precision del modelo en validación: 13.5 %
# Epoca: 9/10, Paso: 50/80, Perdida:1.16868
# Precision del modelo en entrenamiento: 56.125 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 60/80, Perdida:1.40277
# Precision del modelo en entrenamiento: 60.0 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 70/80, Perdida:1.52309
# Precision del modelo en entrenamiento: 56.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 80/80, Perdida:1.55021
# Precision del modelo en entrenamiento: 53.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 10/80, Perdida:1.63644
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 20/80, Perdida:1.18601
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 30/80, Perdida:1.34256
# Precision del modelo en entrenamiento: 56.625 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 40/80, Perdida:1.34390
# Precision del modelo en entrenamiento: 56.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 50/80, Perdida:1.22737
# Precision del modelo en entrenamiento: 55.625 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 60/80, Perdida:1.67678
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 70/80, Perdida:1.62691
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 80/80, Perdida:1.28248
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 15.0 %
# Termina la evaluación de batchsize: 10

# %% [markdown]
# **batch size: 15**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
train_loader_norm, val_loader_norm = load_normalized_dataset(batch_size = 15)

batch_size = 15
bs = batch_size

  # evaluación de los modelos de cnn
count = 0
for modelo_evaluado in modelos_cnn:
  print("="*90)
  if count == 0:
    print("device: ", device)
    print('arquitectura: Alexnet')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1           
  elif count == 1:
    print("device: ", device)
    print('arquitectura: resnet18')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1        
  elif count == 2:
    print("device: ", device)
    print('arquitectura: vgg11_bn')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1
  else:
    print("device: ", device)
    print('arquitectura: densenet121')
    print("="*90) 
    count += 1

  # entrenamiento
  entrenamiento_cnn1(modelo_evaluado, lr=.001, gamma=0.6,
                       num_classes = 10, num_epochs=10)
# Out:
# ==========================================================================================
# device:  cuda
# arquitectura: Alexnet
# batch size: 15
# ==========================================================================================
# Epoca: 1/10, Paso: 10/54, Perdida:1.67358
# Precision del modelo en entrenamiento: 53.75 %
# Precision del modelo en validación: 45.0 %
# Epoca: 1/10, Paso: 20/54, Perdida:0.93672
# Precision del modelo en entrenamiento: 54.75 %
# Precision del modelo en validación: 41.5 %
# Epoca: 1/10, Paso: 30/54, Perdida:1.30711
# Precision del modelo en entrenamiento: 54.5 %
# Precision del modelo en validación: 42.5 %
# Epoca: 1/10, Paso: 40/54, Perdida:1.23092
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 43.0 %
# Epoca: 1/10, Paso: 50/54, Perdida:1.48289
# Precision del modelo en entrenamiento: 55.625 %
# Precision del modelo en validación: 51.5 %
# Epoca: 2/10, Paso: 10/54, Perdida:1.47485
# Precision del modelo en entrenamiento: 57.125 %
# Precision del modelo en validación: 44.5 %
# Epoca: 2/10, Paso: 20/54, Perdida:1.07739
# Precision del modelo en entrenamiento: 56.375 %
# Precision del modelo en validación: 45.0 %
# Epoca: 2/10, Paso: 30/54, Perdida:1.98065
# Precision del modelo en entrenamiento: 55.75 %
# Precision del modelo en validación: 44.0 %
# Epoca: 2/10, Paso: 40/54, Perdida:1.34229
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 49.0 %
# Epoca: 2/10, Paso: 50/54, Perdida:1.10465
# Precision del modelo en entrenamiento: 56.0 %
# Precision del modelo en validación: 43.5 %
# Epoca: 3/10, Paso: 10/54, Perdida:1.20193
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 44.5 %
# Epoca: 3/10, Paso: 20/54, Perdida:1.17731
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 48.5 %
# Epoca: 3/10, Paso: 30/54, Perdida:1.05669
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 45.5 %
# Epoca: 3/10, Paso: 40/54, Perdida:1.14788
# Precision del modelo en entrenamiento: 57.875 %
# Precision del modelo en validación: 49.0 %
# Epoca: 3/10, Paso: 50/54, Perdida:1.46900
# Precision del modelo en entrenamiento: 56.25 %
# Precision del modelo en validación: 46.0 %
# Epoca: 4/10, Paso: 10/54, Perdida:1.18352
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 45.5 %
# Epoca: 4/10, Paso: 20/54, Perdida:0.94333
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 41.0 %
# Epoca: 4/10, Paso: 30/54, Perdida:1.20591
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 48.0 %
# Epoca: 4/10, Paso: 40/54, Perdida:0.73278
# Precision del modelo en entrenamiento: 58.125 %
# Precision del modelo en validación: 47.5 %
# Epoca: 4/10, Paso: 50/54, Perdida:1.08549
# Precision del modelo en entrenamiento: 59.25 %
# Precision del modelo en validación: 46.5 %
# Epoca: 5/10, Paso: 10/54, Perdida:1.56432
# Precision del modelo en entrenamiento: 59.625 %
# Precision del modelo en validación: 44.0 %
# Epoca: 5/10, Paso: 20/54, Perdida:1.09328
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 45.5 %
# Epoca: 5/10, Paso: 30/54, Perdida:0.90935
# Precision del modelo en entrenamiento: 60.125 %
# Precision del modelo en validación: 45.0 %
# Epoca: 5/10, Paso: 40/54, Perdida:1.04597
# Precision del modelo en entrenamiento: 61.5 %
# Precision del modelo en validación: 47.0 %
# Epoca: 5/10, Paso: 50/54, Perdida:1.27777
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 44.0 %
# Epoca: 6/10, Paso: 10/54, Perdida:1.14886
# Precision del modelo en entrenamiento: 58.875 %
# Precision del modelo en validación: 51.5 %
# Epoca: 6/10, Paso: 20/54, Perdida:1.03450
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 48.5 %
# Epoca: 6/10, Paso: 30/54, Perdida:1.15828
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 42.0 %
# Epoca: 6/10, Paso: 40/54, Perdida:1.22983
# Precision del modelo en entrenamiento: 60.875 %
# Precision del modelo en validación: 45.0 %
# Epoca: 6/10, Paso: 50/54, Perdida:0.89014
# Precision del modelo en entrenamiento: 57.875 %
# Precision del modelo en validación: 48.0 %
# Epoca: 7/10, Paso: 10/54, Perdida:1.49641
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 44.5 %
# Epoca: 7/10, Paso: 20/54, Perdida:1.21114
# Precision del modelo en entrenamiento: 60.375 %
# Precision del modelo en validación: 44.0 %
# Epoca: 7/10, Paso: 30/54, Perdida:0.88740
# Precision del modelo en entrenamiento: 61.0 %
# Precision del modelo en validación: 48.0 %
# Epoca: 7/10, Paso: 40/54, Perdida:0.76638
# Precision del modelo en entrenamiento: 58.5 %
# Precision del modelo en validación: 46.5 %
# Epoca: 7/10, Paso: 50/54, Perdida:1.20805
# Precision del modelo en entrenamiento: 61.625 %
# Precision del modelo en validación: 50.0 %
# Epoca: 8/10, Paso: 10/54, Perdida:1.56721
# Precision del modelo en entrenamiento: 60.375 %
# Precision del modelo en validación: 47.5 %
# Epoca: 8/10, Paso: 20/54, Perdida:1.00319
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 47.5 %
# Epoca: 8/10, Paso: 30/54, Perdida:0.51249
# Precision del modelo en entrenamiento: 56.375 %
# Precision del modelo en validación: 42.0 %
# Epoca: 8/10, Paso: 40/54, Perdida:0.85344
# Precision del modelo en entrenamiento: 59.75 %
# Precision del modelo en validación: 45.0 %
# Epoca: 8/10, Paso: 50/54, Perdida:0.94498
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 48.0 %
# Epoca: 9/10, Paso: 10/54, Perdida:0.89278
# Precision del modelo en entrenamiento: 60.25 %
# Precision del modelo en validación: 50.5 %
# Epoca: 9/10, Paso: 20/54, Perdida:1.28819
# Precision del modelo en entrenamiento: 62.25 %
# Precision del modelo en validación: 44.0 %
# Epoca: 9/10, Paso: 30/54, Perdida:0.87579
# Precision del modelo en entrenamiento: 57.875 %
# Precision del modelo en validación: 45.5 %
# Epoca: 9/10, Paso: 40/54, Perdida:1.16393
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 46.0 %
# Epoca: 9/10, Paso: 50/54, Perdida:0.89465
# Precision del modelo en entrenamiento: 61.25 %
# Precision del modelo en validación: 44.5 %
# Epoca: 10/10, Paso: 10/54, Perdida:1.19150
# Precision del modelo en entrenamiento: 61.25 %
# Precision del modelo en validación: 48.5 %
# Epoca: 10/10, Paso: 20/54, Perdida:0.83610
# Precision del modelo en entrenamiento: 59.375 %
# Precision del modelo en validación: 42.0 %
# Epoca: 10/10, Paso: 30/54, Perdida:0.96027
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 47.0 %
# Epoca: 10/10, Paso: 40/54, Perdida:1.01557
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 48.0 %
# Epoca: 10/10, Paso: 50/54, Perdida:1.34290
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 45.0 %
# ==========================================================================================
# device:  cuda
# arquitectura: resnet18
# batch size: 15
# ==========================================================================================
# Epoca: 1/10, Paso: 10/54, Perdida:1.51122
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 16.5 %
# Epoca: 1/10, Paso: 20/54, Perdida:1.12426
# Precision del modelo en entrenamiento: 49.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 1/10, Paso: 30/54, Perdida:1.24625
# Precision del modelo en entrenamiento: 53.75 %
# Precision del modelo en validación: 11.0 %
# Epoca: 1/10, Paso: 40/54, Perdida:1.35967
# Precision del modelo en entrenamiento: 54.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 1/10, Paso: 50/54, Perdida:1.79671
# Precision del modelo en entrenamiento: 53.0 %
# Precision del modelo en validación: 16.0 %
# Epoca: 2/10, Paso: 10/54, Perdida:1.52400
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 14.5 %
# Epoca: 2/10, Paso: 20/54, Perdida:1.01879
# Precision del modelo en entrenamiento: 54.25 %
# Precision del modelo en validación: 16.0 %
# Epoca: 2/10, Paso: 30/54, Perdida:1.62015
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 14.5 %
# Epoca: 2/10, Paso: 40/54, Perdida:1.25383
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 13.0 %
# Epoca: 2/10, Paso: 50/54, Perdida:1.38338
# Precision del modelo en entrenamiento: 56.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 3/10, Paso: 10/54, Perdida:1.12698
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 14.0 %
# Epoca: 3/10, Paso: 20/54, Perdida:1.16406
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 13.0 %
# Epoca: 3/10, Paso: 30/54, Perdida:0.98617
# Precision del modelo en entrenamiento: 57.75 %
# Precision del modelo en validación: 17.0 %
# Epoca: 3/10, Paso: 40/54, Perdida:1.08061
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 3/10, Paso: 50/54, Perdida:1.25266
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 14.0 %
# Epoca: 4/10, Paso: 10/54, Perdida:1.06949
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 13.5 %
# Epoca: 4/10, Paso: 20/54, Perdida:1.17823
# Precision del modelo en entrenamiento: 62.25 %
# Precision del modelo en validación: 15.5 %
# Epoca: 4/10, Paso: 30/54, Perdida:1.51794
# Precision del modelo en entrenamiento: 60.125 %
# Precision del modelo en validación: 14.5 %
# Epoca: 4/10, Paso: 40/54, Perdida:1.35605
# Precision del modelo en entrenamiento: 59.25 %
# Precision del modelo en validación: 14.0 %
# Epoca: 4/10, Paso: 50/54, Perdida:1.17380
# Precision del modelo en entrenamiento: 56.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 5/10, Paso: 10/54, Perdida:1.60835
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 5/10, Paso: 20/54, Perdida:1.29209
# Precision del modelo en entrenamiento: 59.625 %
# Precision del modelo en validación: 16.0 %
# Epoca: 5/10, Paso: 30/54, Perdida:1.10084
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 16.0 %
# Epoca: 5/10, Paso: 40/54, Perdida:1.14929
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 5/10, Paso: 50/54, Perdida:1.11405
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 13.0 %
# Epoca: 6/10, Paso: 10/54, Perdida:1.31138
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 14.5 %
# Epoca: 6/10, Paso: 20/54, Perdida:1.10734
# Precision del modelo en entrenamiento: 62.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 6/10, Paso: 30/54, Perdida:0.87161
# Precision del modelo en entrenamiento: 62.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 6/10, Paso: 40/54, Perdida:0.90681
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 14.5 %
# Epoca: 6/10, Paso: 50/54, Perdida:1.07714
# Precision del modelo en entrenamiento: 59.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 7/10, Paso: 10/54, Perdida:1.25377
# Precision del modelo en entrenamiento: 61.625 %
# Precision del modelo en validación: 16.5 %
# Epoca: 7/10, Paso: 20/54, Perdida:1.33072
# Precision del modelo en entrenamiento: 60.0 %
# Precision del modelo en validación: 16.0 %
# Epoca: 7/10, Paso: 30/54, Perdida:0.93863
# Precision del modelo en entrenamiento: 60.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 7/10, Paso: 40/54, Perdida:1.18994
# Precision del modelo en entrenamiento: 62.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 7/10, Paso: 50/54, Perdida:1.25193
# Precision del modelo en entrenamiento: 59.25 %
# Precision del modelo en validación: 15.0 %
# Epoca: 8/10, Paso: 10/54, Perdida:1.17623
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 15.0 %
# Epoca: 8/10, Paso: 20/54, Perdida:1.25680
# Precision del modelo en entrenamiento: 60.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 8/10, Paso: 30/54, Perdida:1.02902
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 8/10, Paso: 40/54, Perdida:0.91338
# Precision del modelo en entrenamiento: 64.0 %
# Precision del modelo en validación: 14.5 %
# Epoca: 8/10, Paso: 50/54, Perdida:1.02294
# Precision del modelo en entrenamiento: 60.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 10/54, Perdida:1.12856
# Precision del modelo en entrenamiento: 61.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 20/54, Perdida:1.13913
# Precision del modelo en entrenamiento: 60.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 30/54, Perdida:1.24107
# Precision del modelo en entrenamiento: 61.5 %
# Precision del modelo en validación: 15.5 %
# Epoca: 9/10, Paso: 40/54, Perdida:1.29621
# Precision del modelo en entrenamiento: 62.5 %
# Precision del modelo en validación: 15.5 %
# Epoca: 9/10, Paso: 50/54, Perdida:1.21408
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 15.5 %
# Epoca: 10/10, Paso: 10/54, Perdida:1.03239
# Precision del modelo en entrenamiento: 61.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 20/54, Perdida:0.97427
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 30/54, Perdida:1.07077
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 40/54, Perdida:0.94327
# Precision del modelo en entrenamiento: 60.125 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 50/54, Perdida:1.12221
# Precision del modelo en entrenamiento: 62.625 %
# Precision del modelo en validación: 15.0 %
# ==========================================================================================
# device:  cuda
# arquitectura: vgg11_bn
# batch size: 15
# ==========================================================================================
# Epoca: 1/10, Paso: 10/54, Perdida:1.65072
# Precision del modelo en entrenamiento: 54.875 %
# Precision del modelo en validación: 17.0 %
# Epoca: 1/10, Paso: 20/54, Perdida:0.81593
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 16.5 %
# Epoca: 1/10, Paso: 30/54, Perdida:0.99727
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 14.0 %
# Epoca: 1/10, Paso: 40/54, Perdida:0.93330
# Precision del modelo en entrenamiento: 54.625 %
# Precision del modelo en validación: 17.5 %
# Epoca: 1/10, Paso: 50/54, Perdida:1.76605
# Precision del modelo en entrenamiento: 56.375 %
# Precision del modelo en validación: 21.5 %
# Epoca: 2/10, Paso: 10/54, Perdida:1.00423
# Precision del modelo en entrenamiento: 61.125 %
# Precision del modelo en validación: 18.0 %
# Epoca: 2/10, Paso: 20/54, Perdida:1.06493
# Precision del modelo en entrenamiento: 58.125 %
# Precision del modelo en validación: 22.5 %
# Epoca: 2/10, Paso: 30/54, Perdida:1.44631
# Precision del modelo en entrenamiento: 61.625 %
# Precision del modelo en validación: 20.5 %
# Epoca: 2/10, Paso: 40/54, Perdida:1.43614
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 16.5 %
# Epoca: 2/10, Paso: 50/54, Perdida:1.17414
# Precision del modelo en entrenamiento: 57.875 %
# Precision del modelo en validación: 17.0 %
# Epoca: 3/10, Paso: 10/54, Perdida:0.66465
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 19.0 %
# Epoca: 3/10, Paso: 20/54, Perdida:0.81469
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 23.0 %
# Epoca: 3/10, Paso: 30/54, Perdida:0.74787
# Precision del modelo en entrenamiento: 61.625 %
# Precision del modelo en validación: 19.0 %
# Epoca: 3/10, Paso: 40/54, Perdida:0.86997
# Precision del modelo en entrenamiento: 63.5 %
# Precision del modelo en validación: 18.0 %
# Epoca: 3/10, Paso: 50/54, Perdida:1.12126
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 19.5 %
# Epoca: 4/10, Paso: 10/54, Perdida:0.97116
# Precision del modelo en entrenamiento: 61.5 %
# Precision del modelo en validación: 19.0 %
# Epoca: 4/10, Paso: 20/54, Perdida:0.82720
# Precision del modelo en entrenamiento: 62.625 %
# Precision del modelo en validación: 18.0 %
# Epoca: 4/10, Paso: 30/54, Perdida:0.89344
# Precision del modelo en entrenamiento: 61.5 %
# Precision del modelo en validación: 17.5 %
# Epoca: 4/10, Paso: 40/54, Perdida:0.82434
# Precision del modelo en entrenamiento: 62.0 %
# Precision del modelo en validación: 17.5 %
# Epoca: 4/10, Paso: 50/54, Perdida:1.11948
# Precision del modelo en entrenamiento: 62.5 %
# Precision del modelo en validación: 20.0 %
# Epoca: 5/10, Paso: 10/54, Perdida:1.60502
# Precision del modelo en entrenamiento: 60.25 %
# Precision del modelo en validación: 17.0 %
# Epoca: 5/10, Paso: 20/54, Perdida:1.22329
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 20.0 %
# Epoca: 5/10, Paso: 30/54, Perdida:0.75628
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 19.5 %
# Epoca: 5/10, Paso: 40/54, Perdida:1.50275
# Precision del modelo en entrenamiento: 62.5 %
# Precision del modelo en validación: 20.5 %
# Epoca: 5/10, Paso: 50/54, Perdida:0.95750
# Precision del modelo en entrenamiento: 62.75 %
# Precision del modelo en validación: 18.5 %
# Epoca: 6/10, Paso: 10/54, Perdida:1.77439
# Precision del modelo en entrenamiento: 63.375 %
# Precision del modelo en validación: 20.0 %
# Epoca: 6/10, Paso: 20/54, Perdida:0.78878
# Precision del modelo en entrenamiento: 60.125 %
# Precision del modelo en validación: 16.0 %
# Epoca: 6/10, Paso: 30/54, Perdida:0.65132
# Precision del modelo en entrenamiento: 64.25 %
# Precision del modelo en validación: 23.0 %
# Epoca: 6/10, Paso: 40/54, Perdida:0.86438
# Precision del modelo en entrenamiento: 62.625 %
# Precision del modelo en validación: 19.0 %
# Epoca: 6/10, Paso: 50/54, Perdida:0.69754
# Precision del modelo en entrenamiento: 63.75 %
# Precision del modelo en validación: 20.0 %
# Epoca: 7/10, Paso: 10/54, Perdida:1.56155
# Precision del modelo en entrenamiento: 62.125 %
# Precision del modelo en validación: 19.0 %
# Epoca: 7/10, Paso: 20/54, Perdida:1.23761
# Precision del modelo en entrenamiento: 65.0 %
# Precision del modelo en validación: 21.0 %
# Epoca: 7/10, Paso: 30/54, Perdida:1.05214
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 19.5 %
# Epoca: 7/10, Paso: 40/54, Perdida:0.92129
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 20.0 %
# Epoca: 7/10, Paso: 50/54, Perdida:1.18706
# Precision del modelo en entrenamiento: 63.5 %
# Precision del modelo en validación: 20.5 %
# Epoca: 8/10, Paso: 10/54, Perdida:1.07690
# Precision del modelo en entrenamiento: 63.125 %
# Precision del modelo en validación: 21.5 %
# Epoca: 8/10, Paso: 20/54, Perdida:1.16044
# Precision del modelo en entrenamiento: 62.125 %
# Precision del modelo en validación: 17.5 %
# Epoca: 8/10, Paso: 30/54, Perdida:0.96029
# Precision del modelo en entrenamiento: 63.25 %
# Precision del modelo en validación: 22.0 %
# Epoca: 8/10, Paso: 40/54, Perdida:0.51425
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 21.5 %
# Epoca: 8/10, Paso: 50/54, Perdida:0.90218
# Precision del modelo en entrenamiento: 63.0 %
# Precision del modelo en validación: 20.0 %
# Epoca: 9/10, Paso: 10/54, Perdida:0.84482
# Precision del modelo en entrenamiento: 60.0 %
# Precision del modelo en validación: 20.5 %
# Epoca: 9/10, Paso: 20/54, Perdida:1.00823
# Precision del modelo en entrenamiento: 61.625 %
# Precision del modelo en validación: 17.5 %
# Epoca: 9/10, Paso: 30/54, Perdida:0.96588
# Precision del modelo en entrenamiento: 63.0 %
# Precision del modelo en validación: 17.0 %
# Epoca: 9/10, Paso: 40/54, Perdida:1.01260
# Precision del modelo en entrenamiento: 62.625 %
# Precision del modelo en validación: 19.0 %
# Epoca: 9/10, Paso: 50/54, Perdida:1.20321
# Precision del modelo en entrenamiento: 62.375 %
# Precision del modelo en validación: 20.0 %
# Epoca: 10/10, Paso: 10/54, Perdida:0.91646
# Precision del modelo en entrenamiento: 62.625 %
# Precision del modelo en validación: 20.5 %
# Epoca: 10/10, Paso: 20/54, Perdida:0.81192
# Precision del modelo en entrenamiento: 60.25 %
# Precision del modelo en validación: 18.0 %
# Epoca: 10/10, Paso: 30/54, Perdida:0.79820
# Precision del modelo en entrenamiento: 62.625 %
# Precision del modelo en validación: 17.0 %
# Epoca: 10/10, Paso: 40/54, Perdida:1.29613
# Precision del modelo en entrenamiento: 61.625 %
# Precision del modelo en validación: 19.5 %
# Epoca: 10/10, Paso: 50/54, Perdida:0.99208
# Precision del modelo en entrenamiento: 64.0 %
# Precision del modelo en validación: 22.0 %
# ==========================================================================================
# device:  cuda
# arquitectura: densenet121
# ==========================================================================================
# Epoca: 1/10, Paso: 10/54, Perdida:1.56197
# Precision del modelo en entrenamiento: 54.375 %
# Precision del modelo en validación: 16.0 %
# Epoca: 1/10, Paso: 20/54, Perdida:1.23431
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 16.0 %
# Epoca: 1/10, Paso: 30/54, Perdida:1.30852
# Precision del modelo en entrenamiento: 55.75 %
# Precision del modelo en validación: 10.5 %
# Epoca: 1/10, Paso: 40/54, Perdida:1.36832
# Precision del modelo en entrenamiento: 53.5 %
# Precision del modelo en validación: 16.5 %
# Epoca: 1/10, Paso: 50/54, Perdida:1.88401
# Precision del modelo en entrenamiento: 55.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 2/10, Paso: 10/54, Perdida:1.22454
# Precision del modelo en entrenamiento: 60.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 2/10, Paso: 20/54, Perdida:1.35838
# Precision del modelo en entrenamiento: 57.625 %
# Precision del modelo en validación: 17.0 %
# Epoca: 2/10, Paso: 30/54, Perdida:1.56326
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 15.5 %
# Epoca: 2/10, Paso: 40/54, Perdida:1.36128
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 16.0 %
# Epoca: 2/10, Paso: 50/54, Perdida:1.19987
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 14.5 %
# Epoca: 3/10, Paso: 10/54, Perdida:1.37605
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 13.5 %
# Epoca: 3/10, Paso: 20/54, Perdida:0.79846
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 15.0 %
# Epoca: 3/10, Paso: 30/54, Perdida:1.13772
# Precision del modelo en entrenamiento: 64.0 %
# Precision del modelo en validación: 15.5 %
# Epoca: 3/10, Paso: 40/54, Perdida:0.94722
# Precision del modelo en entrenamiento: 60.125 %
# Precision del modelo en validación: 18.5 %
# Epoca: 3/10, Paso: 50/54, Perdida:1.26246
# Precision del modelo en entrenamiento: 63.5 %
# Precision del modelo en validación: 16.0 %
# Epoca: 4/10, Paso: 10/54, Perdida:1.06258
# Precision del modelo en entrenamiento: 63.0 %
# Precision del modelo en validación: 15.5 %
# Epoca: 4/10, Paso: 20/54, Perdida:1.39119
# Precision del modelo en entrenamiento: 62.25 %
# Precision del modelo en validación: 18.0 %
# Epoca: 4/10, Paso: 30/54, Perdida:1.24398
# Precision del modelo en entrenamiento: 63.5 %
# Precision del modelo en validación: 18.5 %
# Epoca: 4/10, Paso: 40/54, Perdida:1.07607
# Precision del modelo en entrenamiento: 62.75 %
# Precision del modelo en validación: 17.5 %
# Epoca: 4/10, Paso: 50/54, Perdida:1.30118
# Precision del modelo en entrenamiento: 61.125 %
# Precision del modelo en validación: 16.5 %
# Epoca: 5/10, Paso: 10/54, Perdida:1.61149
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 16.5 %
# Epoca: 5/10, Paso: 20/54, Perdida:1.04042
# Precision del modelo en entrenamiento: 61.75 %
# Precision del modelo en validación: 18.0 %
# Epoca: 5/10, Paso: 30/54, Perdida:0.79526
# Precision del modelo en entrenamiento: 62.625 %
# Precision del modelo en validación: 17.5 %
# Epoca: 5/10, Paso: 40/54, Perdida:1.31718
# Precision del modelo en entrenamiento: 61.375 %
# Precision del modelo en validación: 16.0 %
# Epoca: 5/10, Paso: 50/54, Perdida:1.06446
# Precision del modelo en entrenamiento: 62.75 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 10/54, Perdida:1.43224
# Precision del modelo en entrenamiento: 62.375 %
# Precision del modelo en validación: 17.5 %
# Epoca: 6/10, Paso: 20/54, Perdida:0.72950
# Precision del modelo en entrenamiento: 63.625 %
# Precision del modelo en validación: 16.5 %
# Epoca: 6/10, Paso: 30/54, Perdida:0.92613
# Precision del modelo en entrenamiento: 63.375 %
# Precision del modelo en validación: 16.5 %
# Epoca: 6/10, Paso: 40/54, Perdida:0.81107
# Precision del modelo en entrenamiento: 65.875 %
# Precision del modelo en validación: 16.0 %
# Epoca: 6/10, Paso: 50/54, Perdida:0.95919
# Precision del modelo en entrenamiento: 64.5 %
# Precision del modelo en validación: 16.5 %
# Epoca: 7/10, Paso: 10/54, Perdida:1.48149
# Precision del modelo en entrenamiento: 64.125 %
# Precision del modelo en validación: 18.0 %
# Epoca: 7/10, Paso: 20/54, Perdida:1.41878
# Precision del modelo en entrenamiento: 64.625 %
# Precision del modelo en validación: 17.5 %
# Epoca: 7/10, Paso: 30/54, Perdida:0.92684
# Precision del modelo en entrenamiento: 65.375 %
# Precision del modelo en validación: 16.5 %
# Epoca: 7/10, Paso: 40/54, Perdida:1.14542
# Precision del modelo en entrenamiento: 65.75 %
# Precision del modelo en validación: 17.0 %
# Epoca: 7/10, Paso: 50/54, Perdida:1.12764
# Precision del modelo en entrenamiento: 63.375 %
# Precision del modelo en validación: 17.0 %
# Epoca: 8/10, Paso: 10/54, Perdida:1.04088
# Precision del modelo en entrenamiento: 64.375 %
# Precision del modelo en validación: 17.5 %
# Epoca: 8/10, Paso: 20/54, Perdida:0.91196
# Precision del modelo en entrenamiento: 63.5 %
# Precision del modelo en validación: 17.5 %
# Epoca: 8/10, Paso: 30/54, Perdida:1.18211
# Precision del modelo en entrenamiento: 62.375 %
# Precision del modelo en validación: 17.0 %
# Epoca: 8/10, Paso: 40/54, Perdida:0.81957
# Precision del modelo en entrenamiento: 65.625 %
# Precision del modelo en validación: 16.5 %
# Epoca: 8/10, Paso: 50/54, Perdida:1.22650
# Precision del modelo en entrenamiento: 61.25 %
# Precision del modelo en validación: 17.0 %
# Epoca: 9/10, Paso: 10/54, Perdida:1.37096
# Precision del modelo en entrenamiento: 63.875 %
# Precision del modelo en validación: 17.0 %
# Epoca: 9/10, Paso: 20/54, Perdida:0.94545
# Precision del modelo en entrenamiento: 64.75 %
# Precision del modelo en validación: 17.0 %
# Epoca: 9/10, Paso: 30/54, Perdida:1.01453
# Precision del modelo en entrenamiento: 64.875 %
# Precision del modelo en validación: 17.0 %
# Epoca: 9/10, Paso: 40/54, Perdida:1.41053
# Precision del modelo en entrenamiento: 64.375 %
# Precision del modelo en validación: 17.0 %
# Epoca: 9/10, Paso: 50/54, Perdida:1.27152
# Precision del modelo en entrenamiento: 62.5 %
# Precision del modelo en validación: 17.0 %
# Epoca: 10/10, Paso: 10/54, Perdida:1.00920
# Precision del modelo en entrenamiento: 65.5 %
# Precision del modelo en validación: 17.0 %
# Epoca: 10/10, Paso: 20/54, Perdida:0.88367
# Precision del modelo en entrenamiento: 66.125 %
# Precision del modelo en validación: 17.0 %
# Epoca: 10/10, Paso: 30/54, Perdida:1.00183
# Precision del modelo en entrenamiento: 64.75 %
# Precision del modelo en validación: 17.0 %
# Epoca: 10/10, Paso: 40/54, Perdida:0.92005
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 17.0 %
# Epoca: 10/10, Paso: 50/54, Perdida:1.19410
# Precision del modelo en entrenamiento: 65.625 %
# Precision del modelo en validación: 17.0 %

# %% [markdown]
# ****batch size: 20****

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
batch_size = 20
bs = batch_size

train_loader_norm, val_loader_norm = load_normalized_dataset(batch_size)
  # evaluación de los modelos de cnn
count = 0
for modelo_evaluado in modelos_cnn:
  print("="*90)
  if count == 0:
    print("device: ", device)
    print('arquitectura: Alexnet')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1           
  elif count == 1:
    print("device: ", device)
    print('arquitectura: resnet18')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1        
  elif count == 2:
    print("device: ", device)
    print('arquitectura: vgg11_bn')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1
  else:
    print("device: ", device)
    print('arquitectura: densenet121')
    print("="*90) 
    count += 1

  # entrenamiento
  entrenamiento_cnn1(modelo_evaluado, lr=.001, gamma=0.6,
                       num_classes = 10, num_epochs=10)
# Out:
# ==========================================================================================
# device:  cuda
# arquitectura: Alexnet
# batch size: 15
# ==========================================================================================
# Epoca: 1/10, Paso: 10/40, Perdida:0.73645
# Precision del modelo en entrenamiento: 49.375 %
# Precision del modelo en validación: 39.0 %
# Epoca: 1/10, Paso: 20/40, Perdida:0.75085
# Precision del modelo en entrenamiento: 51.5 %
# Precision del modelo en validación: 39.0 %
# Epoca: 1/10, Paso: 30/40, Perdida:1.33473
# Precision del modelo en entrenamiento: 53.25 %
# Precision del modelo en validación: 36.5 %
# Epoca: 1/10, Paso: 40/40, Perdida:1.63799
# Precision del modelo en entrenamiento: 50.375 %
# Precision del modelo en validación: 45.5 %
# Epoca: 2/10, Paso: 10/40, Perdida:1.40857
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 43.0 %
# Epoca: 2/10, Paso: 20/40, Perdida:1.18938
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 45.0 %
# Epoca: 2/10, Paso: 30/40, Perdida:1.16988
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 43.0 %
# Epoca: 2/10, Paso: 40/40, Perdida:1.31993
# Precision del modelo en entrenamiento: 54.5 %
# Precision del modelo en validación: 38.0 %
# Epoca: 3/10, Paso: 10/40, Perdida:0.90620
# Precision del modelo en entrenamiento: 58.125 %
# Precision del modelo en validación: 44.5 %
# Epoca: 3/10, Paso: 20/40, Perdida:1.04269
# Precision del modelo en entrenamiento: 54.75 %
# Precision del modelo en validación: 41.5 %
# Epoca: 3/10, Paso: 30/40, Perdida:1.34247
# Precision del modelo en entrenamiento: 55.875 %
# Precision del modelo en validación: 40.0 %
# Epoca: 3/10, Paso: 40/40, Perdida:1.19458
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 47.0 %
# Epoca: 4/10, Paso: 10/40, Perdida:1.34281
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 44.0 %
# Epoca: 4/10, Paso: 20/40, Perdida:1.71418
# Precision del modelo en entrenamiento: 55.75 %
# Precision del modelo en validación: 45.0 %
# Epoca: 4/10, Paso: 30/40, Perdida:0.95070
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 46.5 %
# Epoca: 4/10, Paso: 40/40, Perdida:1.02888
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 42.5 %
# Epoca: 5/10, Paso: 10/40, Perdida:1.55510
# Precision del modelo en entrenamiento: 55.0 %
# Precision del modelo en validación: 43.0 %
# Epoca: 5/10, Paso: 20/40, Perdida:1.10463
# Precision del modelo en entrenamiento: 58.5 %
# Precision del modelo en validación: 44.5 %
# Epoca: 5/10, Paso: 30/40, Perdida:1.47439
# Precision del modelo en entrenamiento: 55.375 %
# Precision del modelo en validación: 44.5 %
# Epoca: 5/10, Paso: 40/40, Perdida:1.30792
# Precision del modelo en entrenamiento: 54.625 %
# Precision del modelo en validación: 46.0 %
# Epoca: 6/10, Paso: 10/40, Perdida:1.33905
# Precision del modelo en entrenamiento: 54.625 %
# Precision del modelo en validación: 45.5 %
# Epoca: 6/10, Paso: 20/40, Perdida:0.96416
# Precision del modelo en entrenamiento: 60.5 %
# Precision del modelo en validación: 44.5 %
# Epoca: 6/10, Paso: 30/40, Perdida:1.22030
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 41.5 %
# Epoca: 6/10, Paso: 40/40, Perdida:1.15552
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 46.5 %
# Epoca: 7/10, Paso: 10/40, Perdida:0.97053
# Precision del modelo en entrenamiento: 58.875 %
# Precision del modelo en validación: 51.5 %
# Epoca: 7/10, Paso: 20/40, Perdida:0.69692
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 40.5 %
# Epoca: 7/10, Paso: 30/40, Perdida:1.22816
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 41.5 %
# Epoca: 7/10, Paso: 40/40, Perdida:1.35399
# Precision del modelo en entrenamiento: 57.125 %
# Precision del modelo en validación: 48.5 %
# Epoca: 8/10, Paso: 10/40, Perdida:0.88043
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 43.5 %
# Epoca: 8/10, Paso: 20/40, Perdida:1.44684
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 46.0 %
# Epoca: 8/10, Paso: 30/40, Perdida:1.20210
# Precision del modelo en entrenamiento: 59.125 %
# Precision del modelo en validación: 43.0 %
# Epoca: 8/10, Paso: 40/40, Perdida:1.22890
# Precision del modelo en entrenamiento: 59.5 %
# Precision del modelo en validación: 44.5 %
# Epoca: 9/10, Paso: 10/40, Perdida:1.42306
# Precision del modelo en entrenamiento: 59.375 %
# Precision del modelo en validación: 42.0 %
# Epoca: 9/10, Paso: 20/40, Perdida:0.84451
# Precision del modelo en entrenamiento: 60.0 %
# Precision del modelo en validación: 43.5 %
# Epoca: 9/10, Paso: 30/40, Perdida:1.28454
# Precision del modelo en entrenamiento: 55.625 %
# Precision del modelo en validación: 47.0 %
# Epoca: 9/10, Paso: 40/40, Perdida:0.97524
# Precision del modelo en entrenamiento: 56.0 %
# Precision del modelo en validación: 47.5 %
# Epoca: 10/10, Paso: 10/40, Perdida:1.17766
# Precision del modelo en entrenamiento: 61.125 %
# Precision del modelo en validación: 48.5 %
# Epoca: 10/10, Paso: 20/40, Perdida:1.16424
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 43.5 %
# Epoca: 10/10, Paso: 30/40, Perdida:1.15751
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 41.0 %
# Epoca: 10/10, Paso: 40/40, Perdida:1.29838
# Precision del modelo en entrenamiento: 58.875 %
# Precision del modelo en validación: 45.5 %
# Termina la evaluación de batchsize: 15
# ==========================================================================================
# device:  cuda
# arquitectura: resnet18
# batch size: 15
# ==========================================================================================
# Epoca: 1/10, Paso: 10/40, Perdida:2.22541
# Precision del modelo en entrenamiento: 14.625 %
# Precision del modelo en validación: 11.0 %
# Epoca: 1/10, Paso: 20/40, Perdida:1.94057
# Precision del modelo en entrenamiento: 21.0 %
# Precision del modelo en validación: 10.5 %
# Epoca: 1/10, Paso: 30/40, Perdida:2.02318
# Precision del modelo en entrenamiento: 25.25 %
# Precision del modelo en validación: 9.0 %
# Epoca: 1/10, Paso: 40/40, Perdida:2.21536
# Precision del modelo en entrenamiento: 32.875 %
# Precision del modelo en validación: 9.0 %
# Epoca: 2/10, Paso: 10/40, Perdida:1.88374
# Precision del modelo en entrenamiento: 39.5 %
# Precision del modelo en validación: 12.5 %
# Epoca: 2/10, Paso: 20/40, Perdida:2.04757
# Precision del modelo en entrenamiento: 42.0 %
# Precision del modelo en validación: 11.0 %
# Epoca: 2/10, Paso: 30/40, Perdida:2.01140
# Precision del modelo en entrenamiento: 41.125 %
# Precision del modelo en validación: 8.5 %
# Epoca: 2/10, Paso: 40/40, Perdida:1.68493
# Precision del modelo en entrenamiento: 45.875 %
# Precision del modelo en validación: 14.0 %
# Epoca: 3/10, Paso: 10/40, Perdida:1.77055
# Precision del modelo en entrenamiento: 46.5 %
# Precision del modelo en validación: 14.0 %
# Epoca: 3/10, Paso: 20/40, Perdida:1.72325
# Precision del modelo en entrenamiento: 49.875 %
# Precision del modelo en validación: 13.0 %
# Epoca: 3/10, Paso: 30/40, Perdida:1.64825
# Precision del modelo en entrenamiento: 48.75 %
# Precision del modelo en validación: 13.0 %
# Epoca: 3/10, Paso: 40/40, Perdida:1.72671
# Precision del modelo en entrenamiento: 49.0 %
# Precision del modelo en validación: 14.0 %
# Epoca: 4/10, Paso: 10/40, Perdida:1.45294
# Precision del modelo en entrenamiento: 50.25 %
# Precision del modelo en validación: 11.5 %
# Epoca: 4/10, Paso: 20/40, Perdida:1.42897
# Precision del modelo en entrenamiento: 49.5 %
# Precision del modelo en validación: 13.0 %
# Epoca: 4/10, Paso: 30/40, Perdida:1.61987
# Precision del modelo en entrenamiento: 51.125 %
# Precision del modelo en validación: 12.0 %
# Epoca: 4/10, Paso: 40/40, Perdida:1.69103
# Precision del modelo en entrenamiento: 51.125 %
# Precision del modelo en validación: 14.5 %
# Epoca: 5/10, Paso: 10/40, Perdida:1.72019
# Precision del modelo en entrenamiento: 50.875 %
# Precision del modelo en validación: 14.5 %
# Epoca: 5/10, Paso: 20/40, Perdida:1.58292
# Precision del modelo en entrenamiento: 50.125 %
# Precision del modelo en validación: 11.5 %
# Epoca: 5/10, Paso: 30/40, Perdida:1.58593
# Precision del modelo en entrenamiento: 51.875 %
# Precision del modelo en validación: 13.0 %
# Epoca: 5/10, Paso: 40/40, Perdida:1.44287
# Precision del modelo en entrenamiento: 51.25 %
# Precision del modelo en validación: 15.5 %
# Epoca: 6/10, Paso: 10/40, Perdida:1.60493
# Precision del modelo en entrenamiento: 50.875 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 20/40, Perdida:1.52856
# Precision del modelo en entrenamiento: 52.0 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 30/40, Perdida:1.69425
# Precision del modelo en entrenamiento: 48.875 %
# Precision del modelo en validación: 14.0 %
# Epoca: 6/10, Paso: 40/40, Perdida:1.46621
# Precision del modelo en entrenamiento: 52.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 7/10, Paso: 10/40, Perdida:1.54311
# Precision del modelo en entrenamiento: 51.5 %
# Precision del modelo en validación: 14.0 %
# Epoca: 7/10, Paso: 20/40, Perdida:1.24084
# Precision del modelo en entrenamiento: 52.25 %
# Precision del modelo en validación: 13.5 %
# Epoca: 7/10, Paso: 30/40, Perdida:1.61862
# Precision del modelo en entrenamiento: 51.125 %
# Precision del modelo en validación: 13.5 %
# Epoca: 7/10, Paso: 40/40, Perdida:1.67227
# Precision del modelo en entrenamiento: 55.625 %
# Precision del modelo en validación: 14.5 %
# Epoca: 8/10, Paso: 10/40, Perdida:1.49448
# Precision del modelo en entrenamiento: 52.5 %
# Precision del modelo en validación: 14.5 %
# Epoca: 8/10, Paso: 20/40, Perdida:1.54189
# Precision del modelo en entrenamiento: 56.0 %
# Precision del modelo en validación: 14.5 %
# Epoca: 8/10, Paso: 30/40, Perdida:1.45933
# Precision del modelo en entrenamiento: 54.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 8/10, Paso: 40/40, Perdida:1.59773
# Precision del modelo en entrenamiento: 56.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 10/40, Perdida:1.56234
# Precision del modelo en entrenamiento: 51.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 20/40, Perdida:1.79366
# Precision del modelo en entrenamiento: 53.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 30/40, Perdida:1.40513
# Precision del modelo en entrenamiento: 50.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 9/10, Paso: 40/40, Perdida:1.57173
# Precision del modelo en entrenamiento: 52.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 10/40, Perdida:1.67403
# Precision del modelo en entrenamiento: 53.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 20/40, Perdida:1.41099
# Precision del modelo en entrenamiento: 53.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 30/40, Perdida:1.62917
# Precision del modelo en entrenamiento: 52.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 40/40, Perdida:1.22443
# Precision del modelo en entrenamiento: 53.0 %
# Precision del modelo en validación: 15.0 %
# Termina la evaluación de batchsize: 15
# ==========================================================================================
# device:  cuda
# arquitectura: vgg11_bn
# batch size: 15
# ==========================================================================================
# Epoca: 1/10, Paso: 10/40, Perdida:2.11155
# Precision del modelo en entrenamiento: 31.875 %
# Precision del modelo en validación: 10.5 %
# Epoca: 1/10, Paso: 20/40, Perdida:1.43845
# Precision del modelo en entrenamiento: 39.5 %
# Precision del modelo en validación: 12.5 %
# Epoca: 1/10, Paso: 30/40, Perdida:1.78228
# Precision del modelo en entrenamiento: 44.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 1/10, Paso: 40/40, Perdida:1.59792
# Precision del modelo en entrenamiento: 48.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 2/10, Paso: 10/40, Perdida:1.32298
# Precision del modelo en entrenamiento: 51.875 %
# Precision del modelo en validación: 14.5 %
# Epoca: 2/10, Paso: 20/40, Perdida:1.75581
# Precision del modelo en entrenamiento: 55.875 %
# Precision del modelo en validación: 13.0 %
# Epoca: 2/10, Paso: 30/40, Perdida:1.54708
# Precision del modelo en entrenamiento: 54.625 %
# Precision del modelo en validación: 14.5 %
# Epoca: 2/10, Paso: 40/40, Perdida:1.29141
# Precision del modelo en entrenamiento: 55.625 %
# Precision del modelo en validación: 16.0 %
# Epoca: 3/10, Paso: 10/40, Perdida:1.03703
# Precision del modelo en entrenamiento: 57.875 %
# Precision del modelo en validación: 11.5 %
# Epoca: 3/10, Paso: 20/40, Perdida:1.51517
# Precision del modelo en entrenamiento: 56.5 %
# Precision del modelo en validación: 11.5 %
# Epoca: 3/10, Paso: 30/40, Perdida:1.13718
# Precision del modelo en entrenamiento: 59.125 %
# Precision del modelo en validación: 15.5 %
# Epoca: 3/10, Paso: 40/40, Perdida:1.08687
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 15.5 %
# Epoca: 4/10, Paso: 10/40, Perdida:1.22591
# Precision del modelo en entrenamiento: 59.125 %
# Precision del modelo en validación: 12.0 %
# Epoca: 4/10, Paso: 20/40, Perdida:1.18358
# Precision del modelo en entrenamiento: 61.375 %
# Precision del modelo en validación: 15.0 %
# Epoca: 4/10, Paso: 30/40, Perdida:1.30767
# Precision del modelo en entrenamiento: 59.25 %
# Precision del modelo en validación: 16.0 %
# Epoca: 4/10, Paso: 40/40, Perdida:1.45593
# Precision del modelo en entrenamiento: 58.5 %
# Precision del modelo en validación: 17.0 %
# Epoca: 5/10, Paso: 10/40, Perdida:1.44260
# Precision del modelo en entrenamiento: 59.125 %
# Precision del modelo en validación: 15.5 %
# Epoca: 5/10, Paso: 20/40, Perdida:1.10542
# Precision del modelo en entrenamiento: 59.625 %
# Precision del modelo en validación: 14.0 %
# Epoca: 5/10, Paso: 30/40, Perdida:1.07275
# Precision del modelo en entrenamiento: 61.25 %
# Precision del modelo en validación: 13.0 %
# Epoca: 5/10, Paso: 40/40, Perdida:1.16397
# Precision del modelo en entrenamiento: 59.375 %
# Precision del modelo en validación: 13.0 %
# Epoca: 6/10, Paso: 10/40, Perdida:0.94986
# Precision del modelo en entrenamiento: 62.625 %
# Precision del modelo en validación: 14.5 %
# Epoca: 6/10, Paso: 20/40, Perdida:0.99926
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 15.0 %
# Epoca: 6/10, Paso: 30/40, Perdida:1.27223
# Precision del modelo en entrenamiento: 61.875 %
# Precision del modelo en validación: 16.0 %
# Epoca: 6/10, Paso: 40/40, Perdida:0.78246
# Precision del modelo en entrenamiento: 61.125 %
# Precision del modelo en validación: 18.0 %
# Epoca: 7/10, Paso: 10/40, Perdida:1.11822
# Precision del modelo en entrenamiento: 63.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 7/10, Paso: 20/40, Perdida:0.79318
# Precision del modelo en entrenamiento: 62.125 %
# Precision del modelo en validación: 15.0 %
# Epoca: 7/10, Paso: 30/40, Perdida:0.87228
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 7/10, Paso: 40/40, Perdida:1.07428
# Precision del modelo en entrenamiento: 62.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 8/10, Paso: 10/40, Perdida:1.19333
# Precision del modelo en entrenamiento: 61.0 %
# Precision del modelo en validación: 12.5 %
# Epoca: 8/10, Paso: 20/40, Perdida:1.33301
# Precision del modelo en entrenamiento: 63.0 %
# Precision del modelo en validación: 11.0 %
# Epoca: 8/10, Paso: 30/40, Perdida:0.99895
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 14.5 %
# Epoca: 8/10, Paso: 40/40, Perdida:1.50107
# Precision del modelo en entrenamiento: 59.25 %
# Precision del modelo en validación: 13.5 %
# Epoca: 9/10, Paso: 10/40, Perdida:1.46026
# Precision del modelo en entrenamiento: 60.75 %
# Precision del modelo en validación: 12.5 %
# Epoca: 9/10, Paso: 20/40, Perdida:1.12349
# Precision del modelo en entrenamiento: 61.375 %
# Precision del modelo en validación: 14.5 %
# Epoca: 9/10, Paso: 30/40, Perdida:1.37073
# Precision del modelo en entrenamiento: 63.125 %
# Precision del modelo en validación: 13.5 %
# Epoca: 9/10, Paso: 40/40, Perdida:1.17765
# Precision del modelo en entrenamiento: 61.625 %
# Precision del modelo en validación: 14.0 %
# Epoca: 10/10, Paso: 10/40, Perdida:1.15550
# Precision del modelo en entrenamiento: 60.5 %
# Precision del modelo en validación: 13.0 %
# Epoca: 10/10, Paso: 20/40, Perdida:1.18507
# Precision del modelo en entrenamiento: 61.25 %
# Precision del modelo en validación: 14.5 %
# Epoca: 10/10, Paso: 30/40, Perdida:1.19505
# Precision del modelo en entrenamiento: 60.875 %
# Precision del modelo en validación: 15.0 %
# Epoca: 10/10, Paso: 40/40, Perdida:0.90980
# Precision del modelo en entrenamiento: 61.125 %
# Precision del modelo en validación: 14.5 %
# Termina la evaluación de batchsize: 15
# ==========================================================================================
# device:  cuda
# arquitectura: densenet121
# ==========================================================================================
# Epoca: 1/10, Paso: 10/40, Perdida:2.32799
# Precision del modelo en entrenamiento: 19.875 %
# Precision del modelo en validación: 10.0 %
# Epoca: 1/10, Paso: 20/40, Perdida:1.78587
# Precision del modelo en entrenamiento: 30.5 %
# Precision del modelo en validación: 11.5 %
# Epoca: 1/10, Paso: 30/40, Perdida:1.99922
# Precision del modelo en entrenamiento: 34.875 %
# Precision del modelo en validación: 13.5 %
# Epoca: 1/10, Paso: 40/40, Perdida:2.05221
# Precision del modelo en entrenamiento: 40.0 %
# Precision del modelo en validación: 12.0 %
# Epoca: 2/10, Paso: 10/40, Perdida:1.79582
# Precision del modelo en entrenamiento: 46.5 %
# Precision del modelo en validación: 10.5 %
# Epoca: 2/10, Paso: 20/40, Perdida:1.72989
# Precision del modelo en entrenamiento: 44.625 %
# Precision del modelo en validación: 12.5 %
# Epoca: 2/10, Paso: 30/40, Perdida:1.76955
# Precision del modelo en entrenamiento: 47.25 %
# Precision del modelo en validación: 11.0 %
# Epoca: 2/10, Paso: 40/40, Perdida:1.44732
# Precision del modelo en entrenamiento: 50.75 %
# Precision del modelo en validación: 12.0 %
# Epoca: 3/10, Paso: 10/40, Perdida:1.57233
# Precision del modelo en entrenamiento: 48.25 %
# Precision del modelo en validación: 12.0 %
# Epoca: 3/10, Paso: 20/40, Perdida:1.84196
# Precision del modelo en entrenamiento: 52.125 %
# Precision del modelo en validación: 12.0 %
# Epoca: 3/10, Paso: 30/40, Perdida:1.41188
# Precision del modelo en entrenamiento: 54.875 %
# Precision del modelo en validación: 12.0 %
# Epoca: 3/10, Paso: 40/40, Perdida:1.50774
# Precision del modelo en entrenamiento: 57.125 %
# Precision del modelo en validación: 12.5 %
# Epoca: 4/10, Paso: 10/40, Perdida:1.39504
# Precision del modelo en entrenamiento: 53.125 %
# Precision del modelo en validación: 10.5 %
# Epoca: 4/10, Paso: 20/40, Perdida:1.37865
# Precision del modelo en entrenamiento: 55.125 %
# Precision del modelo en validación: 10.5 %
# Epoca: 4/10, Paso: 30/40, Perdida:1.49643
# Precision del modelo en entrenamiento: 54.25 %
# Precision del modelo en validación: 10.5 %
# Epoca: 4/10, Paso: 40/40, Perdida:1.27289
# Precision del modelo en entrenamiento: 58.25 %
# Precision del modelo en validación: 12.5 %
# Epoca: 5/10, Paso: 10/40, Perdida:1.70946
# Precision del modelo en entrenamiento: 59.25 %
# Precision del modelo en validación: 12.5 %
# Epoca: 5/10, Paso: 20/40, Perdida:1.42619
# Precision del modelo en entrenamiento: 57.125 %
# Precision del modelo en validación: 12.5 %
# Epoca: 5/10, Paso: 30/40, Perdida:1.38739
# Precision del modelo en entrenamiento: 58.875 %
# Precision del modelo en validación: 12.5 %
# Epoca: 5/10, Paso: 40/40, Perdida:1.31757
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 13.5 %
# Epoca: 6/10, Paso: 10/40, Perdida:1.35296
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 12.5 %
# Epoca: 6/10, Paso: 20/40, Perdida:1.38628
# Precision del modelo en entrenamiento: 61.0 %
# Precision del modelo en validación: 13.0 %
# Epoca: 6/10, Paso: 30/40, Perdida:1.42347
# Precision del modelo en entrenamiento: 60.25 %
# Precision del modelo en validación: 13.0 %
# Epoca: 6/10, Paso: 40/40, Perdida:1.17778
# Precision del modelo en entrenamiento: 59.75 %
# Precision del modelo en validación: 13.5 %
# Epoca: 7/10, Paso: 10/40, Perdida:1.40966
# Precision del modelo en entrenamiento: 58.0 %
# Precision del modelo en validación: 11.5 %
# Epoca: 7/10, Paso: 20/40, Perdida:1.11030
# Precision del modelo en entrenamiento: 59.0 %
# Precision del modelo en validación: 12.0 %
# Epoca: 7/10, Paso: 30/40, Perdida:1.49120
# Precision del modelo en entrenamiento: 59.875 %
# Precision del modelo en validación: 12.5 %
# Epoca: 7/10, Paso: 40/40, Perdida:1.54329
# Precision del modelo en entrenamiento: 58.375 %
# Precision del modelo en validación: 12.5 %
# Epoca: 8/10, Paso: 10/40, Perdida:1.47334
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 12.5 %
# Epoca: 8/10, Paso: 20/40, Perdida:1.71889
# Precision del modelo en entrenamiento: 60.25 %
# Precision del modelo en validación: 12.0 %
# Epoca: 8/10, Paso: 30/40, Perdida:1.32273
# Precision del modelo en entrenamiento: 57.375 %
# Precision del modelo en validación: 12.5 %
# Epoca: 8/10, Paso: 40/40, Perdida:1.47579
# Precision del modelo en entrenamiento: 57.0 %
# Precision del modelo en validación: 11.5 %
# Epoca: 9/10, Paso: 10/40, Perdida:1.43411
# Precision del modelo en entrenamiento: 59.125 %
# Precision del modelo en validación: 11.5 %
# Epoca: 9/10, Paso: 20/40, Perdida:1.51073
# Precision del modelo en entrenamiento: 58.75 %
# Precision del modelo en validación: 12.5 %
# Epoca: 9/10, Paso: 30/40, Perdida:1.52624
# Precision del modelo en entrenamiento: 57.875 %
# Precision del modelo en validación: 12.5 %
# Epoca: 9/10, Paso: 40/40, Perdida:1.43273
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 12.5 %
# Epoca: 10/10, Paso: 10/40, Perdida:1.55714
# Precision del modelo en entrenamiento: 57.5 %
# Precision del modelo en validación: 12.5 %
# Epoca: 10/10, Paso: 20/40, Perdida:1.53106
# Precision del modelo en entrenamiento: 58.625 %
# Precision del modelo en validación: 12.5 %
# Epoca: 10/10, Paso: 30/40, Perdida:1.50397
# Precision del modelo en entrenamiento: 55.5 %
# Precision del modelo en validación: 12.5 %
# Epoca: 10/10, Paso: 40/40, Perdida:1.14166
# Precision del modelo en entrenamiento: 57.25 %
# Precision del modelo en validación: 12.5 %
# Termina la evaluación de batchsize: 15

# %% [markdown]
# **batch size: 25**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

batch_size = 25
bs = batch_size

train_loader_norm, val_loader_norm = load_normalized_dataset(batch_size)

  # evaluación de los modelos de cnn
count = 0
for modelo_evaluado in modelos_cnn:
  print("="*90)
  if count == 0:
    print("device: ", device)
    print('arquitectura: Alexnet')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1           
  elif count == 1:
    print("device: ", device)
    print('arquitectura: resnet18')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1        
  elif count == 2:
    print("device: ", device)
    print('arquitectura: vgg11_bn')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1
  else:
    print("device: ", device)
    print('arquitectura: densenet121')
    print("="*90) 
    count += 1

  # entrenamiento
  entrenamiento_cnn1(modelo_evaluado, lr=.001, gamma=0.6,
                       num_classes = 10, num_epochs=10)
# Out:
# ==========================================================================================
# device:  cuda
# arquitectura: Alexnet
# batch size: 25
# ==========================================================================================
# Epoca: 1/10, Paso: 10/32, Perdida:2.03671
# Precision del modelo en entrenamiento: 34.125 %
# Precision del modelo en validación: 24.5 %
# Epoca: 1/10, Paso: 20/32, Perdida:1.62902

# %% [markdown]
# **batch size: 30**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

batch_size = 30
bs = batch_size

train_loader_norm, val_loader_norm = load_normalized_dataset(batch_size)
  # evaluación de los modelos de cnn
count = 0
for modelo_evaluado in modelos_cnn:
  print("="*90)
  if count == 0:
    print("device: ", device)
    print('arquitectura: Alexnet')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1           
  elif count == 1:
    print("device: ", device)
    print('arquitectura: resnet18')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1        
  elif count == 2:
    print("device: ", device)
    print('arquitectura: vgg11_bn')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1
  else:
    print("device: ", device)
    print('arquitectura: densenet121')
    print("="*90) 
    count += 1

  # entrenamiento
  entrenamiento_cnn1(modelo_evaluado, lr=.001, gamma=0.6,
                       num_classes = 10, num_epochs=10)
      
  print(f'Termina la evaluación de batchsize: {bs}')

# %%
********************

# %%
bs_list = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
count_bs = 0

for bs in bs_list[2:3]:
  # evalue para cada tamaño de batch en la lista
  train_loader_norm, val_loader_norm = load_normalized_dataset(batch_size = bs)
  # evaluación de los modelos de cnn
  count = 0
  for modelo_evaluado in modelos_cnn:
    print("="*90)
    if count == 0:
      print("device: ", device)
      print('arquitectura: Alexnet')
      print(f'batch size: {bs}')
      print("="*90) 
      count += 1           
    elif count == 1:
      print("device: ", device)
      print('arquitectura: resnet18')
      print(f'batch size: {bs}')
      print("="*90) 
      count += 1        
    elif count == 2:
      print("device: ", device)
      print('arquitectura: vgg11_bn')
      print(f'batch size: {bs}')
      print("="*90) 
      count += 1
    else:
      print("device: ", device)
      print('arquitectura: densenet121')
      print("="*90) 
      count += 1

    # entrenamiento
    entrenamiento_cnn1(modelo_evaluado, lr=.001, gamma=0.6,
                       num_classes = 10, num_epochs=20)
      
  print(f'Termina la evaluación de batchsize: {bs}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-29848296bc9f> in <module>()
#       4 for bs in bs_list[2:3]:
#       5   # evalue para cada tamaño de batch en la lista
# ----> 6   train_loader_norm, val_loader_norm = load_normalized_dataset(batch_size = bs)
#       7   # evaluación de los modelos de cnn
#       8   count = 0
#
# NameError: name 'load_normalized_dataset' is not defined

# %% [markdown]
# # Anexos

# %% [markdown]
# - Cargador de datos (formato inicial)

# %%
def load_dataset(traindir, testdir):
    bs = 20
    # train set
    data_path = Path(traindir)
    train_dataset = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=torchvision.transforms.ToTensor()
    )
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size  = bs,
        num_workers =  0,
        shuffle     = True
    )
    
    # test set
    data_path = Path(testdir)
    test_dataset = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=torchvision.transforms.ToTensor()
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size  = bs,
        num_workers =  0,
        shuffle     = True
    )
    
    return train_loader , test_loader

# %% [markdown]
# - cargador de datos con normalización (pero no sigue el ejemplo de `torchvision`)

# %%
# nueva función

from torchvision import transforms 

def load_normalized_dataset(batch_size = 15 ,traindir = "img_data/train_data", 
                            valdir = "img_data/test_data"):
    input_size = 224 # para casi todas las arquitecturas es 224 (menos inception)
    
    workers = 0
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
    
    # train loader
    train_loader = torch.utils.data.DataLoader(
        torchvision.datasets.ImageFolder(traindir, transforms.Compose([
            transforms.RandomResizedCrop(input_size),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])),
        batch_size=batch_size, shuffle=True,
        num_workers=workers, pin_memory=True)
    
    # validation loader
    val_loader = torch.utils.data.DataLoader(
        torchvision.datasets.ImageFolder(valdir, transforms.Compose([
            transforms.Resize(input_size),
            transforms.CenterCrop(input_size),
            transforms.ToTensor(),
            normalize,
        ])),
        batch_size=batch_size, shuffle=False,
        num_workers=workers, pin_memory=True)
    
    
    return train_loader , val_loader

# %% [markdown]
# **Redes de capas profundas: modelos**

# %%
import torch.nn as nn    
# ==================
# Red neuronal de 1 capa (500 unidades) escondida con activaciones ReLU
# ==================    
class RedNeuronal1_ReLu(nn.Module):
    def __init__(self, input_size, num_classes):
        super(RedNeuronal1_ReLu, self).__init__() 
        hidden_size = 500
        
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.sigmoid = nn.Sigmoid()
        self.fc2 = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.sigmoid(out)
        out = self.fc2(out)
        return out


# ==================
# Red neuronal de 2 capas escondidas (200 y 60 unidades)
# con activaciones ReLU
# ==================
class RedNeuronal2_ReLu(nn.Module):
    def __init__(self, input_size, num_classes):
        super(RedNeuronal2_ReLu, self).__init__() 
        
        self.drop_out = nn.Dropout()
        hidden_size1 = 200
        hidden_size2 = 60
        
        # 1ra capa escondida
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu = nn.ReLU()
        # 2da capa escondida
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        # capa Output
        self.fc3 = nn.Linear(hidden_size2, num_classes)
        
    def forward(self, x):
        
        # 1ra capa escondida
        out = self.fc1(x)
        out = self.relu(out)
        # out = self.drop_out(out) 
        # 2da capa escondida
        out = self.fc2(out)
        out = self.relu(out)
        # out = self.drop_out(out) 
        # capa Output
        out = self.fc3(out)

        return out

# ==================
# Red neuronal de 3 capas escondidas (500, 100 y 30 unidades) 
# con activaciones ReLu
# ==================

class RedNeuronal3_ReLu(nn.Module):
    def __init__(self, input_size, num_classes):
        super(RedNeuronal3_ReLu, self).__init__() 
        
        hidden_size1 = 500
        hidden_size2 = 100
        hidden_size3 = 30  
        
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.fc4 = nn.Linear(hidden_size3, num_classes)
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.fc3(out)
        out = self.fc4(out)
        return out

# ==================
# Red neuronal de 5 capas escondidas (500, 300, 100, 50, 30 unidades)
# con activaciones ReLu
# ==================
class RedNeuronal5_ReLu(nn.Module):
    def __init__(self, input_size, num_classes):
        super(RedNeuronal5_ReLu, self).__init__() 
        
        hidden_size1 = 500
        hidden_size2 = 300
        hidden_size3 = 100
        hidden_size4 = 50
        hidden_size5 = 30
        
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.fc5 = nn.Linear(hidden_size4, hidden_size5) 
        self.fc6 = nn.Linear(hidden_size5, num_classes) 
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.fc3(out)
        out = self.fc4(out)
        out = self.fc5(out)
        out = self.fc6(out)
        return out

# %% [markdown]
# **Entrenamiento, perdida y gráficas para las redes profundas**

# %%
def precision(model, prueba=True):
    """
    Esta función calcula la precisión del modelo
    ARGS:
      * model: modelo definido en pytorch -
            model(input_size, num_classes).to(device)
      * Prueba = True: calcular la precisión sobre train_data
               = False: calcular la precisión sobre test_data
    """
    correct, total = (0,0)
    loader = test_loader if prueba else train_loader
    with torch.no_grad():
        for xi, yi in loader:
            xi = xi.reshape(-1, 3*216*216).to(device)
            yi = yi.to(device)
            output = model(xi)
            _, predicted = torch.max(output.data, 1)
            total += yi.size(0)
            correct += (predicted == yi).sum().item()

    if loader == test_loader:
      print(f'Precision del modelo en {total} canciones: {100 * correct / total} %')
    else: None

    return correct/total

def perdida(model, prueba=True):
    """
    Esta función evalúa la función de pérdida del modelo
    ARGS:
      * model: modelo definido en pytorch -
            model(input_size, num_classes).to(device)
      * Prueba = True: computar la f. de pérdida sobre train_data
                = False: computar la f. de pérdida sobre test_data
    """    
    trainset_loss = 0.0
    loader = test_loader if prueba else train_loader
    with torch.no_grad():
        for xi, yi in loader:
            xi = xi.reshape(-1, 3*216*216).to(device)
            yi = yi.to(device)
            output = model(xi)
            loss = loss_function(output, yi)
            batch_loss = loss.item() * yi.size(0)
            trainset_loss += batch_loss
    return trainset_loss
        
# Función para generar gráficas

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

    
def graficas(epocas,perd_train,perd_test,prec_train,prec_test):
    """
    Esta función grafica en dos subpáneles el desempeño del modelo
        - Panel 1,1: Función de pérdida en entrenamiento y prueba
        - Panel 1,2: Precisión en entrenamiento y prueba
    """
    
    plt.figure(figsize=(8,9))
    #fig.set_figheight(8)
    #fig.set_figwidth(9)
    # función de pérdida
    plt.subplot(2, 1, 1)
    plt.plot(epocas, perd_train, '-', color='tab:cyan', label = 'Entrenamiento')
    plt.plot(epocas, perd_test, '-', color='tab:red', label = 'Prueba')
    plt.title(f'Desempeño iterativo del modelo', fontweight="bold")
    plt.ylabel('Función de pérdida')
    plt.legend(loc='upper left')
    
    # precisión
    plt.subplot(2, 1, 2)
    plt.plot(epocas, prec_train, '-', color='tab:cyan')
    plt.plot(epocas, prec_test,'-' ,color='tab:red')
    plt.xlabel('Época')
    plt.ylabel('Precisión')
    #fig.tight_layout()
    plt.show()

def entrenamiento_redesProf(model, input_size= 3*216*216, lr=0.001, num_epochs=10, num_classes=10, gamma=0.6):
  #model = RedNeuronal2_ReLU(input_size, num_classes).to(device)
  loss_function = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=lr)
  scheduler=ExponentialLR(optimizer, gamma, last_epoch=-1)

  # vectores de resultados  
  perd_train = []
  perd_test  = []
  prec_train = []
  prec_test  = []
  epocas = []
  i=0
  # ==================
  # Entrenamiento del modelo
  # ==================
  for epoch in range(num_epochs):
        for i, (xi, yi) in enumerate(train_loader):
            xi = xi.reshape(-1, 3*216*216).to(device) 
            yi = yi.to(device) 
            # Propagacion para adelante
            output = model(xi) 
            loss = loss_function(output, yi) 
            # Propagacion para atras y paso de optimizacion
            optimizer.zero_grad() 
            loss.backward()
            optimizer.step() 

            if (i+1) % 10 == 0:
                print(color.END + 'Epoca: {}/{}, Paso: {}/{}, Perdida:{:.5f}'.format(epoch+1,
                       num_epochs, i+1, len(train_loader), loss.item()))

                # guarda datos por época        
                perd_train.append(perdida(model, prueba=False))
                perd_test.append(perdida(model, prueba=True))
                prec_train.append(precision(model, prueba=False))
                prec_test.append(precision(model, prueba=True))
                epocas.append(epoch+1+((i+1)/len(train_loader)))
    
    # gráfica por modelo
  print(color.BLUE + '='*30)
  print(color.BLUE + f'Tasa de aprendizaje: {lr}')
  graficas(epocas, perd_train, perd_test, prec_train, prec_test)
  print(color.BLUE + '='*30)

# %% [markdown]
# **Entrenamiento, perdida y gráficas para las redes convolucionales**

# %%
## funciones con esquema anterior (utiliza los datos sin normalizar)
# no estandariza los datos para usar torchvision

def precision1(model, prueba=True):
    """
    Esta función calcula la precisión del modelo
    ARGS:
      * model: modelo definido en pytorch -
            model(input_size, num_classes).to(device)
      * Prueba = True: calcular la precisión sobre train_data
               = False: calcular la precisión sobre test_data
    """
    correct, total = (0,0)
    loader = test_loader if prueba else train_loader
    with torch.no_grad():
        for xi, yi in loader:
            yi = yi.to(device)
            output = model(xi)
            _, predicted = torch.max(output.data, 1)
            total += yi.size(0)
            correct += (predicted == yi).sum().item()    
        
    return correct/total

def perdida1(model, prueba=True):
    """
    Esta función evalúa la función de pérdida del modelo
    ARGS:
      * model: modelo definido en pytorch -
            model(input_size, num_classes).to(device)
      * Prueba = True: computar la f. de pérdida sobre train_data
                = False: computar la f. de pérdida sobre test_data
    """    
    trainset_loss = 0.0
    loader = test_loader if prueba else train_loader
    with torch.no_grad():
        for xi, yi in loader:
            yi = yi.to(device)
            output = model(xi)
            loss = loss_function(output, yi)
            batch_loss = loss.item() * yi.size(0)
            trainset_loss += batch_loss
    return trainset_loss

# función para entrenar las arquitecturas de redes convolucionales

def entrenamiento_cnn(model, lr=.01, gamma=0.6, num_classes = 10):    
    loss_function = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    # define al ajustador de lr
    scheduler = ExponentialLR(optimizer, gamma, last_epoch=-1)

    torch.manual_seed(123456789)
    perd_train = []
    perd_test  = []
    prec_train = []
    prec_test  = []
    epocas  = []
    
# ==================
# Entrenamiento del modelo
# ==================
    for epoch in range(num_epochs):
        for i, (xi, yi) in enumerate(train_loader):
           # xi = xi.reshape(-1, 28*28).to(device) # imagenes y reshape se cargan a CPU - comentar
            yi = yi.to(device) # etiquetas  clasificación se carga a CPU
            # Propagacion para adelante
            output = model(xi) # prediccion del modelo
            loss = loss_function(output, yi) # evaluacion de la funcion de perdida
            # Propagacion para atras y paso de optimizacion
            optimizer.zero_grad() 
            loss.backward()
            # actualizar parámetros del modelo
            optimizer.step()
            
            if (i+1) % 10 == 0:
                print(color.END + 'Epoca: {}/{}, Paso: {}/{}, Perdida:{:.5f}'.format(epoch+1,
                       num_epochs, i+1, len(train_loader), loss.item()))
            
                # guarda datos por época        
                perd_train.append(perdida1(model, prueba=False))
                perd_test.append(perdida1(model, prueba=True))
                prec_train.append(precision1(model, prueba=False))
                prec_test.append(precision1(model, prueba=True))
                epocas.append(epoch+1+((i+1)/len(train_loader)))
                
         # se ajusta la magnitud de la lr exp. en cada época
        scheduler.step()
    
    # gráfica por modelo
    print(color.BLUE + '='*50)
    print(color.BLUE + f'Tasa de aprendizaje inicial: {lr}')
    graficas(epocas, perd_train, perd_test, prec_train, prec_test)
    print(color.BLUE + '='*50)

# %% [markdown]
# - Funciones para evaluar modelos precargados de `torchvision`

# %%
# funciones para entrenamiento de redes convolucionales precargadas en torchvision
# usando datos normalizados

def precision_1(model, prueba=True):
    """
    Esta función calcula la precisión del modelo
    ARGS:
      * model: modelo definido en pytorch -
            model(input_size, num_classes).to(device)
      * Prueba = True: calcular la precisión sobre train_data
               = False: calcular la precisión sobre test_data
    """
    correct, total = (0,0)
    loader = val_loader_norm if prueba else train_loader_norm
    with torch.no_grad():
        for xi, yi in loader:
            yi = yi.to(device)
            xi = xi.to(device)
            output = model(xi)
            _, predicted = torch.max(output.data, 1)
            total += yi.size(0)
            correct += (predicted == yi).sum().item()    
    
    if loader == val_loader_norm:
        print(f'Precision del modelo en validación: {100 * correct / total} %')
    else:
      print(f'Precision del modelo en entrenamiento: {100 * correct / total} %')
        
    return correct/total

def perdida_1(model, prueba=True):
    """
    Esta función evalúa la función de pérdida del modelo
    ARGS:
      * model: modelo definido en pytorch -
            model(input_size, num_classes).to(device)
      * Prueba = True: computar la f. de pérdida sobre train_data
                = False: computar la f. de pérdida sobre test_data
    """    
    loss_function = nn.CrossEntropyLoss()
    trainset_loss = 0.0
    loader = val_loader_norm if prueba else train_loader_norm
    with torch.no_grad():
        for xi, yi in loader:
            yi = yi.to(device)
            xi = xi.to(device)
            output = model(xi)
            loss = loss_function(output, yi)
            batch_loss = loss.item() * yi.size(0)
            trainset_loss += batch_loss
    return trainset_loss

def entrenamiento_cnn1(model, lr=.001, gamma=0.6, num_classes = 10, num_epochs=10):   
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
    model = model.to(device)
    loss_function = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    # define al ajustador de lr
    scheduler = ExponentialLR(optimizer, gamma, last_epoch=-1)

    torch.manual_seed(123456789)
    perd_train = []
    perd_test  = []
    prec_train = []
    prec_test  = []
    epocas  = []
    # ==================
    # Entrenamiento del modelo
    # ==================
    for epoch in range(num_epochs):
        for i, (xi, yi) in enumerate(train_loader_norm):
           # xi = xi.reshape(-1, 28*28).to(device) # imagenes y reshape se cargan a CPU - comentar
            xi = xi.to(device)
            yi = yi.to(device) # etiquetas  clasificación se carga a CPU
            # Propagacion para adelante
            output = model(xi) # prediccion del modelo
            loss = loss_function(output, yi) # evaluacion de la funcion de perdida
            # Propagacion para atras y paso de optimizacion
            optimizer.zero_grad() 
            loss.backward()
            # actualizar parámetros del modelo
            optimizer.step()
            
            if (i+1) % 10 == 0:
                print(color.END + 'Epoca: {}/{}, Paso: {}/{}, Perdida:{:.5f}'.format(epoch+1,
                       num_epochs, i+1, len(train_loader_norm), loss.item()))
            
                # guarda datos por época        
                perd_train.append(perdida_1(model, prueba=False))
                perd_test.append(perdida_1(model, prueba=True))
                prec_train.append(precision_1(model, prueba=False))
                prec_test.append(precision_1(model, prueba=True))
                epocas.append(epoch+1+((i+1)/len(train_loader_norm)))
                
         # se ajusta la magnitud de la lr exp. en cada época
        scheduler.step()
    
    # gráfica por modelo
    graficas(epocas, perd_train, perd_test, prec_train, prec_test)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
train_loader_norm, val_loader_norm = load_normalized_dataset(batch_size = 15)

batch_size = 15
bs = batch_size

  # evaluación de los modelos de cnn
count = 0
for modelo_evaluado in modelos_cnn:
  print("="*90)
  if count == 0:
    print("device: ", device)
    print('arquitectura: Alexnet')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1           
  elif count == 1:
    print("device: ", device)
    print('arquitectura: resnet18')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1        
  elif count == 2:
    print("device: ", device)
    print('arquitectura: vgg11_bn')
    print(f'batch size: {bs}')
    print("="*90) 
    count += 1
  else:
    print("device: ", device)
    print('arquitectura: densenet121')
    print("="*90) 
    count += 1

  # entrenamiento
  entrenamiento_cnn1(modelo_evaluado, lr=.001, gamma=0.6,
                       num_classes = 10, num_epochs=10)

# %% [markdown]
# **Modelos de redes convolucionales propios**

# %%
import torch.nn.functional as F
dropout_prob = 0.5 

class RedConvolucional_test(nn.Module):
    def __init__(self, num_classes=10):
        super(RedConvolucional_test, self).__init__()
        # a) Capa convolucional con activaciones ReLU, tamaño de kernel 3, 
        # stride 1, y salida de 12 canales.
        self.drop_out = nn.Dropout()
        
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, out_channels = 100, kernel_size=9), # , stride=1, padding=1
            nn.BatchNorm2d(100),
            nn.ReLU(),
            nn.MaxPool2d(9,9)) # , stride=2
        # b) Capa densa con 200 unidades y activaciones ReLu
        self.layer4 = nn.Sequential(
            nn.Linear(52900, 10),
            nn.ReLU())
        # capa output : clasificación a 10 clases
        self.fc = nn.Linear(10, num_classes)  

    def forward(self, x):
        out = self.layer1(x)
        out = self.drop_out(out)
        out = out.reshape(out.size(0), -1)
        # capas densas
        out = self.layer4(out)
#        out = self.drop_out(out)       
        out = self.fc(out)
        return out

# %% [markdown]
# **`TorchVision` tutorial**
#
# Pasos sugeridos en tutorial de `torchvision`
# **Nota:** Aún hay problemas por solucionar en la etapa de implementación final

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, is_inception=False):
    since = time.time()

    val_acc_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.
                    if is_inception and phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
# función para ajustar modelos pre-cargados
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# ==============
# data loaders
# ==============
# Data augmentation and normalization for training
# Just normalization for validation
from torchvision import datasets, models, transforms
import os

input_size = 224

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# ==============
# optimizador
# ==============
# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(params_to_update, lr=0.001) # para SGD , momentum=0.9

# ==============
# función de pérdida
# ==============
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()


# ==============
# Train and evaluate
# ==============
model_ft, hist = train_model(model_ft, 
                             dataloaders_dict, 
                             criterion, 
                             optimizer_ft, 
                             num_epochs=num_epochs, 
                             is_inception=False)
